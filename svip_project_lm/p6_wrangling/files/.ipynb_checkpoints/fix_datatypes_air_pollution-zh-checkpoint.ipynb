# %% [markdown]
# # 修正 `air_pollution_score` 数据类型
# - 2008：将字符串转换成浮点
# - 2018：将整数转换成浮点

# %%
# 加载数据集
import pandas as pd

df_08 = pd.read_csv('data_08.csv')
df_18 = pd.read_csv('data_18.csv')

# %%
# 尝试使用 Pandas 的 to_numeric 或 astype 功能将
# 2008 air_pollution_score 列转换成浮点——无法转换
df_08['air_pollution_score']= df_08['air_pollution_score'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3b41ca376cc0> in <module>
#       1 # 尝试使用 Pandas 的 to_numeric 或 astype 功能将
#       2 # 2008 air_pollution_score 列转换成浮点——无法转换
# ----> 3 df_08['air_pollution_score']= df_08['air_pollution_score'].astype(float)
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     728
#     729     if copy:
# --> 730         return arr.astype(dtype, copy=True)
#     731     return arr.view(dtype)
#     732
#
# ValueError: could not convert string to float: '7/7'

# %% [markdown]
# # 解决问题
# 这个问题看起来不像数据类型转换那样简单。根据上述错误，第 582 行的值是 "6/4"。我们检验一下。

# %%
df_08.iloc[582]
# Out:
# model                   CHRYSLER PT Cruiser Convertible
# displ                                               2.4
# cyl                                             (4 cyl)
# trans                                           Auto-L4
# drive                                               2WD
# fuel                                           Gasoline
# cert_region                                          FA
# veh_class                                     small car
# air_pollution_score                                   6
# city_mpg                                             19
# hwy_mpg                                              24
# cmb_mpg                                              21
# greenhouse_gas_score                                  6
# smartway                                             no
# Name: 582, dtype: object

# %% [markdown]
# # 存在这个问题的不只是空气污染分数！
# mpg 列和温室气体分数也存在同样的问题。这可能是它们都被保存为字符串的原因。根据我在 PDF 文档中找到的 [这个链接](http://www.fueleconomy.gov/feg/findacarhelp.shtml#airPollutionScore)，
#
# > “如果车辆采用多种燃料提供动力，应该提供每个燃料类型的估值。”
#
# 所以，采用混合动力的所有车辆，例如上面这辆车（采用乙醇和天然气），它们的字符串具有两个值，每种燃料为一个值。这有点复杂，我将给你展示如何用 2008 数据集实现这个效果，之后你用 2018 数据集尝试一下。

# %%
# 首先，获取 2008 年的所有混合动力
hb_08 = df_08[df_08['fuel'].str.contains('/')]

### 使用shape可以看到数据行列是多少
hb_08.shape
# Out:
# (72, 14)

# %% [markdown]
# 好像这个数据集只有一个混合动力车，而 2018 年有很多。但是别担心，现在进行的步骤对它同样适用！

# %%
# 2018年的混合动力
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18.shape
# Out:
# (160, 14)

# %% [markdown]
# 提取每个混合动力行，把它们分成两个新行，一行是第一种燃料类型的值（"/" 前面的值），另一行是第二种燃料类型的值（"/" 后面的值）。现在用两个数据框把它们分开。

# %%
# 创建 2008 混合动力数据框的两个副本
df1 = hb_08.copy()  # 每个混合动力车第一种燃料类型的数据
df2 = hb_18.copy()  # 每个混合动力车第二种燃料类型的数据

# 每个数据应该如下所示
df1
# Out:
#                              model  displ      cyl    trans drive  \
# 316       CHEVROLET Avalanche 1500    5.3  (8 cyl)  Auto-L4   2WD
# 317       CHEVROLET Avalanche 1500    5.3  (8 cyl)  Auto-L4   4WD
# 321       CHEVROLET Avalanche 1500    5.3  (8 cyl)  Auto-L4   2WD
# 322       CHEVROLET Avalanche 1500    5.3  (8 cyl)  Auto-L4   4WD
# 380         CHEVROLET Express 1500    5.3  (8 cyl)  Auto-L4   4WD
# 381         CHEVROLET Express 1500    5.3  (8 cyl)  Auto-L4   2WD
# 386         CHEVROLET Express 2500    5.3  (8 cyl)  Auto-L4   2WD
# 416               CHEVROLET Impala    3.5  (6 cyl)  Auto-L4   2WD
# 417               CHEVROLET Impala    3.9  (6 cyl)  Auto-L4   2WD
# 429         CHEVROLET Silverado 15    5.3  (8 cyl)  Auto-L4   2WD
# 430         CHEVROLET Silverado 15    5.3  (8 cyl)  Auto-L4   4WD
# 437         CHEVROLET Silverado 15    5.3  (8 cyl)  Auto-L4   2WD
# 438         CHEVROLET Silverado 15    5.3  (8 cyl)  Auto-L4   4WD
# 473        CHEVROLET Suburban 1500    5.3  (8 cyl)  Auto-L4   2WD
# 474        CHEVROLET Suburban 1500    5.3  (8 cyl)  Auto-L4   4WD
# 478        CHEVROLET Suburban 1500    5.3  (8 cyl)  Auto-L4   2WD
# 479        CHEVROLET Suburban 1500    5.3  (8 cyl)  Auto-L4   4WD
# 487           CHEVROLET Tahoe 1500    5.3  (8 cyl)  Auto-L4   2WD
# 488           CHEVROLET Tahoe 1500    5.3  (8 cyl)  Auto-L4   4WD
# 490           CHEVROLET Tahoe 1500    5.3  (8 cyl)  Auto-L4   2WD
# 491           CHEVROLET Tahoe 1500    5.3  (8 cyl)  Auto-L4   4WD
# 512             CHEVROLET Uplander    3.9  (6 cyl)  Auto-L4   2WD
# 525             CHEVROLET Van 2500    5.3  (8 cyl)  Auto-L4   4WD
# 561                 CHRYSLER Aspen    4.7  (8 cyl)  Auto-L5   2WD
# 562                 CHRYSLER Aspen    4.7  (8 cyl)  Auto-L5   4WD
# 612               CHRYSLER Sebring    2.7  (6 cyl)  Auto-L4   2WD
# 619   CHRYSLER Sebring Convertible    2.7  (6 cyl)  Auto-L4   2WD
# 637                  DODGE Avenger    2.7  (6 cyl)  Auto-L4   2WD
# 648                  DODGE Caravan    3.3  (6 cyl)  Auto-L4   2WD
# 678                   DODGE Dakota    4.7  (8 cyl)  Auto-L5   2WD
# ...                            ...    ...      ...      ...   ...
# 857                  FORD F150 FFV    5.4  (8 cyl)  Auto-L4   4WD
# 858                  FORD F150 FFV    5.4  (8 cyl)  Auto-L4   2WD
# 859                  FORD F150 FFV    5.4  (8 cyl)  Auto-L4   4WD
# 865           FORD F150 STX SE FFV    5.4  (8 cyl)  Auto-L4   2WD
# 866           FORD F150 STX SE FFV    5.4  (8 cyl)  Auto-L4   2WD
# 992                GMC Savana 1500    5.3  (8 cyl)  Auto-L4   4WD
# 993                GMC Savana 1500    5.3  (8 cyl)  Auto-L4   2WD
# 1008               GMC Savana 2500    5.3  (8 cyl)  Auto-L4   4WD
# 1009               GMC Savana 2500    5.3  (8 cyl)  Auto-L4   2WD
# 1038                 GMC Sierra 15    5.3  (8 cyl)  Auto-L4   2WD
# 1039                 GMC Sierra 15    5.3  (8 cyl)  Auto-L4   4WD
# 1046                 GMC Sierra 15    5.3  (8 cyl)  Auto-L4   2WD
# 1047                 GMC Sierra 15    5.3  (8 cyl)  Auto-L4   4WD
# 1087                GMC Yukon 1500    5.3  (8 cyl)  Auto-L4   2WD
# 1088                GMC Yukon 1500    5.3  (8 cyl)  Auto-L4   4WD
# 1092                GMC Yukon 1500    5.3  (8 cyl)  Auto-L4   2WD
# 1093                GMC Yukon 1500    5.3  (8 cyl)  Auto-L4   4WD
# 1289                JEEP Commander    4.7  (8 cyl)  Auto-L5   2WD
# 1290                JEEP Commander    4.7  (8 cyl)  Auto-L5   4WD
# 1310           JEEP Grand Cherokee    4.7  (8 cyl)  Auto-L5   2WD
# 1311           JEEP Grand Cherokee    4.7  (8 cyl)  Auto-L5   4WD
# 1549            MERCEDES-BENZ C300    3.0  (6 cyl)  Auto-L7   2WD
# 1550            MERCEDES-BENZ C300    3.0  (6 cyl)  Auto-L7   2WD
# 1635     MERCURY Grand Marquis FFV    4.6  (8 cyl)  Auto-L4   2WD
# 1733             MITSUBISHI Raider    4.7  (8 cyl)  Auto-L5   2WD
# 1734             MITSUBISHI Raider    4.7  (8 cyl)  Auto-L5   4WD
# 1764                 NISSAN Armada    5.6  (8 cyl)  Auto-L5   2WD
# 1765                 NISSAN Armada    5.6  (8 cyl)  Auto-L5   4WD
# 1808                  NISSAN Titan    5.6  (8 cyl)  Auto-L5   2WD
# 1809                  NISSAN Titan    5.6  (8 cyl)  Auto-L5   4WD
#
#              fuel cert_region    veh_class air_pollution_score city_mpg  \
# 316   ethanol/gas          FC          SUV                 7/7    11/14
# 317   ethanol/gas          FC          SUV                 7/7    11/14
# 321   ethanol/gas          FC          SUV                 6/6    11/14
# 322   ethanol/gas          FC          SUV                 6/6    11/14
# 380   ethanol/gas          FC          van                 6/6     9/12
# 381   ethanol/gas          FC          van                 6/6     9/12
# 386   ethanol/gas          FC          van                 6/6     9/12
# 416   ethanol/gas          FC    large car                 6/6    14/18
# 417   ethanol/gas          FC    large car                 6/6    13/18
# 429   ethanol/gas          FC       pickup                 7/7    11/15
# 430   ethanol/gas          FC       pickup                 7/7    11/14
# 437   ethanol/gas          FC       pickup                 6/6    11/15
# 438   ethanol/gas          FC       pickup                 6/6    11/14
# 473   ethanol/gas          FC          SUV                 7/7    11/14
# 474   ethanol/gas          FC          SUV                 7/7    11/14
# 478   ethanol/gas          FC          SUV                 6/6    11/14
# 479   ethanol/gas          FC          SUV                 6/6    11/14
# 487   ethanol/gas          FC          SUV                 7/7    11/14
# 488   ethanol/gas          FC          SUV                 7/7    11/14
# 490   ethanol/gas          FC          SUV                 6/6    11/14
# 491   ethanol/gas          FC          SUV                 6/6    11/14
# 512   ethanol/gas          FC      minivan                 6/6    12/16
# 525   ethanol/gas          FC          van                 6/6    10/13
# 561   ethanol/gas          FA          SUV                 3/3     9/14
# 562   ethanol/gas          FA          SUV                 3/3     9/13
# 612   ethanol/gas          FA  midsize car                 3/3    13/19
# 619   ethanol/gas          FA    small car                 3/3    13/18
# 637   ethanol/gas          FA  midsize car                 3/3    13/19
# 648   ethanol/gas          FC      minivan                 6/6    11/17
# 678   ethanol/gas          FA       pickup                 3/3     9/14
# ...           ...         ...          ...                 ...      ...
# 857   ethanol/gas          FC       pickup                 6/6     9/13
# 858   ethanol/gas          FA       pickup                 3/3    10/13
# 859   ethanol/gas          FA       pickup                 3/3     9/13
# 865   ethanol/gas          FA       pickup                 3/3    10/14
# 866   ethanol/gas          FA       pickup                 3/3    10/14
# 992   ethanol/gas          FC          van                 6/6     9/12
# 993   ethanol/gas          FC          van                 6/6     9/12
# 1008  ethanol/gas          FC          van                 6/6    10/13
# 1009  ethanol/gas          FC          van                 6/6     9/12
# 1038  ethanol/gas          FC       pickup                 7/7    11/15
# 1039  ethanol/gas          FC       pickup                 7/7    11/14
# 1046  ethanol/gas          FC       pickup                 6/6    11/15
# 1047  ethanol/gas          FC       pickup                 6/6    11/14
# 1087  ethanol/gas          FC          SUV                 7/7    11/14
# 1088  ethanol/gas          FC          SUV                 7/7    11/14
# 1092  ethanol/gas          FC          SUV                 6/6    11/14
# 1093  ethanol/gas          FC          SUV                 6/6    11/14
# 1289  ethanol/gas          FA          SUV                 3/3     9/14
# 1290  ethanol/gas          FA          SUV                 3/3     9/13
# 1310  ethanol/gas          FA          SUV                 3/3     9/14
# 1311  ethanol/gas          FA          SUV                 3/3     9/14
# 1549  ethanol/gas          FA    small car                 6/6    13/18
# 1550  ethanol/gas          CA    small car                 6/4    13/18
# 1635  ethanol/gas          FC    large car                 6/6    11/15
# 1733  ethanol/gas          FA       pickup                 3/3     9/14
# 1734  ethanol/gas          FA       pickup                 3/3     9/14
# 1764  ethanol/gas          FA          SUV                 6/6     9/12
# 1765  ethanol/gas          FA          SUV                 6/6     9/12
# 1808  ethanol/gas          FA       pickup                 6/6     9/12
# 1809  ethanol/gas          FA       pickup                 6/6     9/12
#
#      hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 316    15/20   12/16                  6/4       no
# 317    14/19   12/16                  6/4       no
# 321    15/20   12/16                  6/4       no
# 322    14/19   12/16                  6/4       no
# 380    12/16   10/14                  4/2       no
# 381    12/16   10/14                  4/2       no
# 386    12/16   10/14                  4/2       no
# 416    21/29   16/22                  8/6       no
# 417    20/28   16/21                  8/6       no
# 429    15/20   13/17                  6/4       no
# 430    14/19   12/16                  6/4       no
# 437    15/20   13/17                  6/4       no
# 438    14/19   12/16                  6/4       no
# 473    15/20   12/16                  6/4       no
# 474    14/19   12/16                  6/4       no
# 478    15/20   12/16                  6/4       no
# 479    14/19   12/16                  6/4       no
# 487    15/20   12/16                  6/4       no
# 488    14/19   12/16                  6/4       no
# 490    15/20   12/16                  6/4       no
# 491    14/19   12/16                  6/4       no
# 512    17/23   14/19                  7/5       no
# 525    12/17   11/15                  5/3       no
# 561    12/19   10/15                  4/3       no
# 562    12/17   10/15                  4/3       no
# 612    20/27   16/22                  8/6       no
# 619    19/26   15/21                  7/6       no
# 637    20/27   16/22                  8/6       no
# 648    17/24   13/19                  6/5       no
# 678    12/19   10/15                  4/3       no
# ...      ...     ...                  ...      ...
# 857    12/17   10/15                  4/3       no
# 858    13/18   11/15                  5/3       no
# 859    12/17   10/15                  4/3       no
# 865    14/19   12/15                  6/3       no
# 866    14/19   12/15                  6/3       no
# 992    12/16   10/14                  4/2       no
# 993    12/16   10/14                  4/2       no
# 1008   12/17   11/15                  5/3       no
# 1009   12/16   10/14                  4/2       no
# 1038   15/20   13/17                  6/4       no
# 1039   14/19   12/16                  6/4       no
# 1046   15/20   13/17                  6/4       no
# 1047   14/19   12/16                  6/4       no
# 1087   15/20   12/16                  6/4       no
# 1088   14/19   12/16                  6/4       no
# 1092   15/20   12/16                  6/4       no
# 1093   14/19   12/16                  6/4       no
# 1289   13/19   10/15                  4/3       no
# 1290   12/18   10/14                  4/2       no
# 1310   13/19   10/15                  4/3       no
# 1311   12/19   10/15                  4/3       no
# 1549   19/25   15/21                  7/6       no
# 1550   19/25   15/21                  7/6       no
# 1635   16/23   13/18                  6/5       no
# 1733   12/19   10/15                  4/3       no
# 1734   12/19   10/15                  4/3       no
# 1764   13/18   10/14                  4/2       no
# 1765   13/17   10/14                  4/2       no
# 1808   13/17   10/14                  4/2       no
# 1809   12/17   10/14                  4/2       no
#
# [72 rows x 14 columns]

# %% [markdown]
# 接下来，我们将使用 Pandas 的 apply 函数。参见 [这里](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.apply.html) 的文档。

# %%
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 316 to 1809
# Data columns (total 14 columns):
# model                   72 non-null object
# displ                   72 non-null float64
# cyl                     66 non-null object
# trans                   66 non-null object
# drive                   66 non-null object
# fuel                    72 non-null object
# cert_region             72 non-null object
# veh_class               72 non-null object
# air_pollution_score     72 non-null object
# city_mpg                66 non-null object
# hwy_mpg                 66 non-null object
# cmb_mpg                 66 non-null object
# greenhouse_gas_score    66 non-null object
# smartway                72 non-null object
# dtypes: float64(1), object(13)
# memory usage: 8.4+ KB

# %%
df1.shape
# Out:
# (72, 14)

# %%
df2.shape
# Out:
# (160, 14)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 55 to 2647
# Data columns (total 14 columns):
# model                   160 non-null object
# displ                   160 non-null float64
# cyl                     160 non-null float64
# trans                   160 non-null object
# drive                   160 non-null object
# fuel                    160 non-null object
# cert_region             160 non-null object
# veh_class               160 non-null object
# air_pollution_score     160 non-null int64
# city_mpg                160 non-null object
# hwy_mpg                 160 non-null object
# cmb_mpg                 160 non-null object
# greenhouse_gas_score    160 non-null int64
# smartway                160 non-null object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 18.8+ KB

# %%
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']


for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])
    # lambda对每个带/的进行分割，分别赋值第1个和第2个拆分元素
print(df1.head(3))
# 看下是否成功
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-11a1b9a2442e> in <module>
#       5 for c in split_columns:
#       6     df1[c] = df1[c].apply(lambda x: x.split("/")[0])
# ----> 7     df2[c] = df2[c].apply(lambda x: x.split("/")[1])
#       8     # lambda对每个带/的进行分割，分别赋值第1个和第2个拆分元素
#       9 print(df1.head(3))
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-11a1b9a2442e> in <lambda>(x)
#       5 for c in split_columns:
#       6     df1[c] = df1[c].apply(lambda x: x.split("/")[0])
# ----> 7     df2[c] = df2[c].apply(lambda x: x.split("/")[1])
#       8     # lambda对每个带/的进行分割，分别赋值第1个和第2个拆分元素
#       9 print(df1.head(3))
#
# AttributeError: 'int' object has no attribute 'split'

# %%
# 将被 "/" 分割的列
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# 对每个数据框副本的每个列应用分割功能
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-d3fa15ac4444> in <module>
#       5 for c in split_columns:
#       6     df1[c] = df1[c].apply(lambda x: x.split("/")[0])
# ----> 7     df2[c] = df2[c].apply(lambda x: x.split("/")[1])
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-22-d3fa15ac4444> in <lambda>(x)
#       5 for c in split_columns:
#       6     df1[c] = df1[c].apply(lambda x: x.split("/")[0])
# ----> 7     df2[c] = df2[c].apply(lambda x: x.split("/")[1])
#
# IndexError: list index out of range

# %%
# 这个数据框包含混合动力车第一种燃料类型的信息
# 也就是 "/" 前面的值
df1
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# 这个数据框包含混合动力车第二种燃料类型的信息
# 也就是 "/" 后面的值
df2
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# 将数据框组合，添加到原始数据框中
new_rows = df1.append(df2)

# 现在每辆车的每种燃料类型都有单独的行
new_rows
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# 丢弃原始混合动力行
df_08.drop(hb_08.index, inplace=True)

# 添加新分割的行
df_08 = df_08.append(new_rows, ignore_index=True)

# %%
# 检查含有 "/" 的所有原始混合动力行是否都已删除
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.shape
# Out:
# (987, 13)

# %% [markdown]
# # 对 2018 数据集重复相同过程

# %%
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# 创建 2018 混合动力数据框 hb_18 的两个副本
df1 = hb_18.copy()
df2 = hb_18.copy()

# %% [markdown]
# ### 分割 `fuel`、`city_mpg`、`hwy_mpg`、`cmb_mpg` 的值
# 不需要分割 `air_pollution_score` 或 `greenhouse_gas_score` 的值，因为这些列在 2018 数据集中已经是整数。

# %%
# 待分割列的列表
split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# 对每个数据框副本的每个列应用分割功能
for d in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
df1
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df2
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# 添加这两个数据框
new_rows = df1.append(df2)

# 从原始 2018 数据框中丢弃每个混合动力行
# 对 hb_18 的索引进行 Pandas 的丢弃功能，实现上述步骤
df_18.drop(hb_18.index, inplace=True)

# 将 new_rows 添加到 df_18
df_18 = df_18.append(new_rows, ignore_index = True)

# %%
# 检查是否已删除
df_18[df_18['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18.shape
# Out:
# (832, 13)

# %% [markdown]
# ### 现在可以继续进行 `air_pollution_score` 所需的更改，如下所示：
# - 2008：将字符串转换成浮点
# - 2018：将整数转换成浮点

# %%
# 对于 2008 空气污染列，将字符串转换成浮点
df_08['air_pollution_score']= df_08['air_pollution_score'].astype(float)

# %%
# 对于 2018 空气污染列，将整数转换成浮点
df_18['air_pollution_score']= df_18['air_pollution_score'].astype(float)

# %%
df_08.to_csv('data_08_1.csv', index=False)
df_18.to_csv('data_18_1.csv', index=False)
