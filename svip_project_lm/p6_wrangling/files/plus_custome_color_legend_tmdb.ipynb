# %% [markdown]
# # 项目：电影数据集探索
#
# ## 目录
# <ul>
# <li><a href="#intro">简介</a></li>
# <li><a href="#wrangling">数据整理</a></li>
# <li><a href="#eda">探索性数据分析</a></li>
# <li><a href="#conclusions">结论</a></li>
# </ul>
#
# <a id='intro'></a>
# ## 简介
#
# > 电影数据集中包含 1 万多条电影信息，信息来源为“电影数据库”（TMDb，The Movie Database），包括用户评分和票房。“演职人员 (cast)”、“电影类别 (genres)”等数据列。

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## 数据整理
#
# > **提示**：在报告的这一部分中载入数据，检查简洁度，然后整理和清理数据集，以便进行分析。请务必将步骤仔细归档，并确定清理决策是否正确。
#
# ### 常规属性

# %%
# 加载数据并打印几行。进行这几项操作，来检查数据
#   类型，以及是否有缺失数据或错误数据的情况。
movies = pd.read_csv('tmdb-movies.csv')
movies.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.
#
#        ...                                                overview runtime  \
# 0      ...       Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# 根据数据集各个字段的情况来看，数据完整性非常高，21个字段中所有的数值型数据（int&float）均不存在缺失值，而在文本型数据中比较重要的演员表、导演、分类数据缺失情况也非常少，而缺失情况比较多的电影网站链接、宣传词数据其分析难度超出了目前的能力水平，暂时不做分析。

# %%
plt.subplot(1,2,1)
(movies['budget']/movies['budget_adj']).hist(figsize=(10,3))
plt.subplot(1,2,2)
(movies['revenue']/movies['revenue_adj']).hist();

# %% [markdown]
# 根据直方图显示整体上电影成本支出以及票房收入调整的比例分布非常相似

# %%
(((movies['revenue']/movies['revenue_adj'])/(movies['budget']/movies['budget_adj'])).max(),
((movies['revenue']/movies['revenue_adj'])/(movies['budget']/movies['budget_adj'])).min())
# Out:
# (1.0000000000000089, 0.9999999999999908)

# %% [markdown]
# 通过比较成本调整比例以及票房调整比例之间的比值，求出该数值最大值和最小值后发现都近似等于1，可见成本以及收入的调整是完全同比的，因此之后对收益率的分析是通过调整前还是调整后的数据不会有差别。
# **通过本次数据分析主要想要探索的问题有：
# 1、每年最受欢迎的电影类别是哪些？
# 2、票房高的电影有哪些特点？**

# %% [markdown]
# ### 字段筛选、数据规整以及缺失数据行删除
#
#
# 紧接上一部分的分析，将数据集进一步规整化
# 主要步骤：
# 1、将本次数据分析中不会用到的tagline、overview、homepage等字段删除
# 2、将日期数据转化为datetime
# 3、清除有缺失值的行

# %%
movies.drop(['tagline','overview','homepage'],axis=1,inplace=True)
movies['release_date'] = pd.to_datetime(movies['release_date'])

# %%
movies = movies[(movies.isnull().sum(axis=1)==0)]

# %% [markdown]
# <a id='eda'></a>
# ## 探索性数据分析
#
#
# ### 每年最受欢迎的电影类别是什么？

# %%
# 以每年票房最高5%的电影作为观众最喜爱的电影，先得到每年调整票房的95分位数
level_95_by_year = {year:np.percentile(movies[movies['release_year']==year]['revenue_adj'],95) for year in movies['release_year'].unique()}

# %%
# 为每行记录打上是否属于当年最高5%票房电影的标签
movies['is_top_5_percent'] = movies['revenue_adj'] > movies['release_year'].map(level_95_by_year)

# %%
GENRES = list(set('|'.join(set(movies['genres'])).title().split('|')))
len(GENRES)
# Out:
# 20

# %% [markdown]
# 所有数据中共有20个不同的电影类别

# %%
# 增加独热码列
for genre in GENRES:
    movies[genre]=False

# %%
movies[genre].value_counts()
# Out:
# False    8665
# Name: War, dtype: int64

# %%
# 将电影类别对应到独热码列
for line in movies.index:
    genre_list = movies.loc[line,'genres'].title().split('|')
    for genre in genre_list:
        movies.loc[line,genre] = True

# %%
movies[genre].value_counts()
# Out:
# False    7326
# True     1339
# Name: Horror, dtype: int64

# %%
movies['is_top_5_percent'].value_counts()
# Out:
# False    8211
# True      454
# Name: is_top_5_percent, dtype: int64

# %%
# 计算没一年最高5%票房电影中各个类型分布有多少部，并存入temp变量
temp = movies[movies['is_top_5_percent'] == True].groupby('release_year').sum().loc[:,'Adventure':'Tv Movie'].copy()

# %%
temp = movies[movies['is_top_5_percent'] == True].copy()

# %%
temp
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# 5      281957  tt1663202    9.110700  135000000   532950503
# 6       87101  tt1340138    8.654359  155000000   440603537
# 7      286217  tt3659388    7.667400  108000000   595380321
# 8      211672  tt2293640    7.404165   74000000  1156730962
# 9      150540  tt2096673    6.326804  175000000   853708609
# 10     206647  tt2379713    6.200282  245000000   880674609
# 10                                            Sam Mendes
# 14                                           Joss Whedon
# 16                                       Olivier Megaton
# 17                                           Peyton Reed
# 18                                       Kenneth Branagh
# 19                                      Francis Lawrence
# 22                                           Brad Peyton
# 23                                    Sam Taylor-Johnson
# 25                                 Christopher McQuarrie
# 27                                        Matthew Vaughn
# 37                                            Peter Sohn
# 46                                           Tim Johnson
# 81                                    Genndy Tartakovsky
# 629                                    Christopher Nolan
# 630                                           James Gunn
# 631                              Joe Russo|Anthony Russo
# 633                                     Francis Lawrence
# 634                                        Peter Jackson
# 635                              Don Hall|Chris Williams
# 637                                             Wes Ball
# 639                                        David Fincher
# ...                                                  ...
# 10228                                     Jonathan Demme
# 10234                                       Renny Harlin
# 10240                                        Nora Ephron
# 10260                                     Sydney Pollack
# 10312                                        Adrian Lyne
# 10398                                Wolfgang Reitherman
# 10401                                      Lewis Gilbert
# 10438                                      Terence Young
# 10443  Joseph L. Mankiewicz|Rouben Mamoulian|Darryl F...
# 10472                                      James Cameron
# 10474                                       Oliver Stone
# 10475                                         Tony Scott
# 10487                                      Leonard Nimoy
# 10495                                   John G. Avildsen
# 10499                                       Peter Faiman
# 10594                                   William Friedkin
# 10595                                       Guy Hamilton
# 10601                                    George Roy Hill
# 10654                                      Arthur Hiller
# 10660                                      George Seaton
# 10689                                      Terence Young
# 10690                                        Robert Wise
# 10724                                      Peter R. Hunt
# 10725                                    George Roy Hill
# 10755                                     Randal Kleiser
# 10756                                     Jeannot Szwarc
# 10758                                     Richard Donner
# 10822                                       Mike Nichols
# 10828                                   Alfred Hitchcock
# 10835                                        Robert Wise
#
#                                                 keywords  runtime  ...    \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island      124  ...
# 1       future|chase|post-apocalyptic|dystopia|australia      120  ...
# 3                  android|spaceship|jedi|space opera|3d      136  ...
# 4                    car race|speed|revenge|suspense|car      137  ...
# 5      father-son relationship|rape|based on novel|mo...      156  ...
# 6      saving the world|artificial intelligence|cybor...      125  ...
# 7            based on novel|mars|nasa|isolation|botanist      141  ...
# 8      assistant|aftercreditsstinger|duringcreditssti...       91  ...
# 9           dream|cartoon|imaginary friend|animation|kid       94  ...
# 10     spy|based on novel|secret agent|sequel|james bond      148  ...
# 14            marvel comic|comic|sequel|superhero|vision      141  ...
# 16             revenge|murder|on the run|fugitive|framed      109  ...
# 17     marvel comic|superhero|aftercreditsstinger|dur...      115  ...
# 18             cinderella|magic|fairy tale|princess|shoe      112  ...
# 19     revolution|strong woman|dystopia|game of death|3d      136  ...
# 22     california|earthquake|catastrophe|disaster fil...      114  ...
# 23     based on novel|billionaire|bdsm|woman director...      125  ...
# 25                                    spy|sequel|mission      131  ...
# 27     spy|great britain|secret organization|secret a...      130  ...
# 37     tyrannosaurus rex|friends|animation|alternate ...       93  ...
# 46       friendship|spaceship|space|alien|alien invasion       94  ...
# 81             transylvania|hotel|witch|technology|magic       89  ...
# 629    saving the world|artificial intelligence|fathe...      169  ...
# 630    marvel comic|spaceship|space|scene during end ...      121  ...
# 631     washington d.c.|future|shield|marvel comic|comic      136  ...
# 633      resistance|post-apocalyptic|dystopia|war|sequel      123  ...
# 634    corruption|elves|dwarves|orcs|middle-earth (to...      144  ...
# 635    brother brother relationship|hero|talent|reven...      102  ...
# 637    based on novel|maze|post-apocalyptic|dystopia|...      113  ...
# 639    falsely accused person|based on novel|marriage...      145  ...
# ...                                                  ...      ...  ...
# 10228                   gay|aids|homophobia|jurors|court      125  ...
# 10234  airplane|hijacking|climbing|heist|mountain cli...      112  ...
# 10240  father-son relationship|lovesickness|journalis...      105  ...
# 10260                  fbi|law|tennessee|lawyer|law firm      154  ...
# 10312  gambling|adultery|love of one's life|shortage ...      117  ...
# 10398              indian|snake|lion|musical|feral child       78  ...
# 10401      london|japan|england|assassination|helicopter      117  ...
# 10438         venice|london|terror|england|assassination      115  ...
# 10443  ancient rome|historical figure|cleopatra|juliu...      248  ...
# 10472  android|extraterrestrial technology|space mari...      137  ...
# 10474         famous score|hero|mine|vietnam war|village      120  ...
# 10475  lovesickness|loss of lover|fighter pilot|self-...      110  ...
# 10487  saving the world|san francisco|uss enterprise-...      119  ...
# 10495   martial arts|karate|okinawa|revanche|self esteem      113  ...
# 10499  new york|prostitute|hotel|journalist|culture c...       97  ...
# 10594  exorcism|holy water|religion and supernatural|...      122  ...
# 10595                   london|new york|bomb|england|spy      121  ...
# 10601           chicago|bet|horse race|repayment|con man      129  ...
# 10654  based on novel|harvard university|college|dram...       99  ...
# 10660  bomb|based on novel|airport|desperation|snow s...      137  ...
# 10689  paris|florida|fighter pilot|sanatorium|secret ...      130  ...
# 10690  austria|world war ii|musical|music competition...      174  ...
# 10724  london|suicide|england|switzerland|secret iden...      142  ...
# 10725             wyoming|historical figure|loot sharing      110  ...
# 10755  flying car|street gang|running|graduation|musical      110  ...
# 10756    mayor|island|police chief|sailing|boat accident      116  ...
# 10758  saving the world|journalist|dc comics|crime fi...      143  ...
# 10822      alcohol|adultery|professor|married couple|son      131  ...
# 10828                              cold war|east germany      128  ...
# 10835            missionary|china|us navy|chinese|battle      182  ...
#
#       Documentary Romance Tv Movie  Foreign  Mystery  Family  Adventure  \
# 0           False   False    False    False    False   False       True
# 1           False   False    False    False    False   False       True
# 3           False   False    False    False    False   False       True
# 4           False   False    False    False    False   False      False
# 5           False   False    False    False    False   False       True
# 6           False   False    False    False    False   False       True
# 7           False   False    False    False    False   False       True
# 8           False   False    False    False    False    True       True
# 9           False   False    False    False    False    True      False
# 10          False   False    False    False    False   False       True
# 14          False   False    False    False    False   False       True
# 16          False   False    False    False    False   False      False
# 17          False   False    False    False    False   False       True
# 18          False    True    False    False    False    True      False
# 19          False   False    False    False    False   False       True
# 22          False   False    False    False    False   False      False
# 23          False    True    False    False    False   False      False
# 25          False   False    False    False    False   False      False
# 27          False   False    False    False    False   False       True
# 37          False   False    False    False    False    True       True
# 46          False   False    False    False    False    True      False
# 81          False   False    False    False    False    True      False
# 629         False   False    False    False    False   False       True
# 630         False   False    False    False    False   False       True
# 631         False   False    False    False    False   False       True
# 633         False   False    False    False    False   False       True
# 634         False   False    False    False    False   False       True
# 635         False   False    False    False    False    True       True
# 637         False   False    False    False     True   False      False
# 639         False   False    False    False     True   False      False
# ...           ...     ...      ...      ...      ...     ...        ...
# 10228       False   False    False    False     True   False      False
# 10234       False   False    False    False    False   False       True
# 10240       False    True    False    False    False   False      False
# 10260       False   False    False    False     True   False      False
# 10312       False   False    False    False    False   False      False
# 10398       False   False    False    False    False    True       True
# 10401       False   False    False    False    False   False       True
# 10438       False   False    False    False    False   False       True
# 10443       False    True    False    False    False   False      False
# 10472       False   False    False    False    False   False      False
# 10474       False   False    False    False    False   False      False
# 10475       False    True    False    False    False   False      False
# 10487       False   False    False    False    False   False       True
# 10495       False    True    False    False    False    True       True
# 10499       False   False    False    False    False   False       True
# 10594       False   False    False    False    False   False      False
# 10595       False   False    False    False    False   False       True
# 10601       False   False    False    False    False   False      False
# 10654       False    True    False    False    False   False      False
# 10660       False   False    False    False    False   False      False
# 10689       False   False    False    False    False   False       True
# 10690       False    True    False    False    False    True      False
# 10724       False   False    False    False    False   False       True
# 10725       False   False    False    False    False   False      False
# 10755       False   False    False    False    False   False      False
# 10756       False   False    False    False    False   False      False
# 10758       False   False    False    False    False   False       True
# 10822       False   False    False    False    False   False      False
# 10828       False   False    False    False     True   False      False
# 10835       False    True    False    False    False   False       True
#
#        Comedy  Thriller    War
# 0       False      True  False
# 1       False      True  False
# 3       False     False  False
# 4       False      True  False
# 5       False      True  False
# 6       False      True  False
# 7       False     False  False
# 8        True     False  False
# 9        True     False  False
# 10      False     False  False
# 14      False     False  False
# 16      False      True  False
# 17      False     False  False
# 18      False     False  False
# 19      False     False   True
# 22      False      True  False
# 23      False     False  False
# 25      False     False  False
# 27       True     False  False
# 37       True     False  False
# 46       True     False  False
# 81       True     False  False
# 629     False     False  False
# 630     False     False  False
# 631     False     False  False
# 633     False      True  False
# 634     False     False  False
# 635      True     False  False
# 637     False      True  False
# 639     False      True  False
# ...       ...       ...    ...
# 10228   False     False  False
# 10234   False      True  False
# 10240    True     False  False
# 10260   False      True  False
# 10312   False     False  False
# 10398   False     False  False
# 10401   False      True  False
# 10438   False      True  False
# 10443   False     False  False
# 10472   False      True  False
# 10474   False     False   True
# 10475   False     False  False
# 10487   False     False  False
# 10495   False     False  False
# 10499    True     False  False
# 10594   False      True  False
# 10595   False      True  False
# 10601    True     False  False
# 10654   False     False  False
# 10660   False      True  False
# 10689   False      True  False
# 10690   False     False  False
# 10724   False      True  False
# 10725   False     False  False
# 10755   False     False  False
# 10756   False      True  False
# 10758   False     False  False
# 10822   False     False  False
# 10828   False      True  False
# 10835   False     False   True
#
# [454 rows x 39 columns]

# %%
temp.loc[:,'Adventure':'Tv Movie'].sum()
# Out:
# Series([], dtype: float64)

# %%
temp.loc[line,'Adventure':'Tv Movie'].sum()
# Out:
# 0

# %%
# 得到每一年最受欢迎的电影类型,并计算在5%受欢迎电影中该类别的占比
temp['top'] = ''
temp['top_count'] = ''
for line in temp.index:
    temp.loc[line,'top_ratio'] = temp.loc[line,'Adventure':'Tv Movie'].max()/temp.loc[line,'Adventure':'Tv Movie'].sum()
    temp.loc[line,'top'] = temp.columns[np.argmax(temp.loc[line,'Adventure':'Tv Movie'])[0]]
#     np.argmax(temp.loc[line,'Adventure':'Tv Movie'])
# np.argmax(temp.loc[1960,'Adventure':'Tv Movie'])
result = temp[['top','top_ratio']]
del temp
result
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-88-b29f837f8a43> in <module>()
#       3 temp['top_count'] = ''
#       4 for line in temp.index:
# ----> 5     temp.loc[line,'top_ratio'] = temp.loc[line,'Adventure':'Tv Movie'].max()/temp.loc[line,'Adventure':'Tv Movie'].sum()
#       6     temp.loc[line,'top'] = temp.columns[np.argmax(temp.loc[line,'Adventure':'Tv Movie'])[0]]
#       7 #     np.argmax(temp.loc[line,'Adventure':'Tv Movie'])
#
# ZeroDivisionError: float division by zero

# %%
result.groupby(['top']).count()

# %%
result['top'].value_counts()

# %%
result['top'].unique()

# %%
# 对于group的数据统一颜色和legend
# 建立图纸
plt.figure(figsize=(20,10))

# 建立color_map对每个bar的颜色进行设定（对应存在color_list)
color = ['slategray','lightcoral','gold','mediumaquamarine','lightskyblue']
color_map = {result['top'].unique()[i]:color[i] for i in range(5)}
color_list = result['top'].map(color_map)

# 因为legend对应的是每次plt
# 所以如果要按照groupby的5个分组设定不同的legend
# 需要将5个分组的内容分别画出来
plt.bar(x=result[result.top == 'Action'].index,height=result[result.top == 'Action']['top_ratio'],
        color='slategray', label = 'Action')
plt.bar(x=result[result.top == 'Adventure'].index,height=result[result.top == 'Adventure']['top_ratio'],
        color='red', label = 'Adventure')
plt.bar(x=result[result.top == 'Horror'].index,height=result[result.top == 'Horror']['top_ratio'], 
        color='yellow', label = 'Horror')
plt.bar(x=result[result.top == 'History'].index,height=result[result.top == 'History']['top_ratio'], 
        color='green', label = 'History')
plt.bar(x=result[result.top == 'Comedy'].index,height=result[result.top == 'Comedy']['top_ratio'], 
        color='blue', label = 'Comedy')

# 增加legend输出
# plt.legend()
# 如果legend小括弧中指定了legend的说明，会覆盖plt中的参数
plt.legend(['Action','Horrow','Testing','Homemake','Free']);

# 参考：
# https://stackoverflow.com/questions/33476401/color-matplotlib-bar-chart-based-on-value
# https://stackoverflow.com/questions/48020667/how-to-add-legend-based-on-color-in-scatterplot-matplotlib
# https://stackoverflow.com/questions/12236566/setting-different-color-for-each-series-in-scatter-plot-on-matplotlib
# https://stackoverflow.com/questions/18973404/setting-different-bar-color-in-matplotlib-python
# https://stackoverflow.com/questions/19184484/how-to-add-group-labels-for-bar-charts-in-matplotlib
# legend官方文档 https://matplotlib.org/users/legend_guide.html

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from itertools import groupby

def test_table():
    data_table = pd.DataFrame({'Room':['Room A']*4 + ['Room B']*4,
                               'Shelf':(['Shelf 1']*2 + ['Shelf 2']*2)*2,
                               'Staple':['Milk','Water','Sugar','Honey','Wheat','Corn','Chicken','Cow'],
                               'Quantity':[10,20,5,6,4,7,2,1],
                               'Ordered':np.random.randint(0,10,8)
                               })
    return data_table

def add_line(ax, xpos, ypos):
    line = plt.Line2D([xpos, xpos], [ypos + .1, ypos],
                      transform=ax.transAxes, color='black')
    line.set_clip_on(False)
    ax.add_line(line)

def label_len(my_index,level):
    labels = my_index.get_level_values(level)
    return [(k, sum(1 for i in g)) for k,g in groupby(labels)]

def label_group_bar_table(ax, df):
    ypos = -.1
    scale = 1./df.index.size
    for level in range(df.index.nlevels)[::-1]:
        pos = 0
        for label, rpos in label_len(df.index,level):
            lxpos = (pos + .5 * rpos)*scale
            ax.text(lxpos, ypos, label, ha='center', transform=ax.transAxes)
            add_line(ax, pos*scale, ypos)
            pos += rpos
        add_line(ax, pos*scale , ypos)
        ypos -= .1

df = test_table().groupby(['Room','Shelf','Staple']).sum()
fig = plt.figure()
ax = fig.add_subplot(111)
df.plot(kind='bar',stacked=True,ax=fig.gca())
#Below 3 lines remove default labels
labels = ['' for item in ax.get_xticklabels()]
ax.set_xticklabels(labels)
ax.set_xlabel('')
label_group_bar_table(ax, df)
fig.subplots_adjust(bottom=.1*df.index.nlevels)
plt.show()

# %% [markdown]
# 以上就是每一年最受欢迎的电影类别，可以看到从始至终Adventure都是观众非常喜爱的一个电影类别。

# %% [markdown]
# ### 票房高的电影有哪些特点？

# %%
# 以10%的比例来认定票房高的电影
high_revenues = movies[movies['revenue_adj']>=np.percentile(movies['revenue_adj'],90)]
low_revenues = movies[movies['revenue_adj']<np.percentile(movies['revenue_adj'],90)]
plt.subplot(1,2,1)
high_revenues['runtime'].hist(figsize=(18,5))
plt.subplot(1,2,2)
low_revenues['runtime'].hist();

# %% [markdown]
# <a id='conclusions'></a>
# ## 结论
#
# > **提示**：最后，你需要总结自己的调查结果。请确保你了解在探索过程中的局限性。如果尚未进行任何统计检验，不要做出任何统计结论。切记不要根据相关关系贸然推导出因果关系！
#
# > **提示**：如果你对自己的研究成果感到满意，应将其副本保存为 HTML 或 PDF 形式。在导出报告之前请检查一遍，确保报告结构完整，信息连贯。应删除所有类似的“提示”引用段，以保持报告中的简洁度。在提交之前，你还需要查看在课程结尾的项目提交页面中的项目审阅规范。
#
# > 如需将报告导出到工作区，你可以运行下面的代码框。如果正确，会返回代码 0，工作区目录下会生成 .html 文件（单击左上角的 jupyter 图标）。也可以通过 **文件** > **下载为** 子菜单下载 html 报告，然后手动上传到工作区目录。完成之后，可以单击右下角的“提交项目”，来提交你的项目。恭喜你！

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
