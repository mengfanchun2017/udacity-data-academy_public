# %% [markdown]
# # 项目：TDMB数据集分析
#
# ## 目录
# <ul>
# <li><a href="#intro">简介</a></li>
# <li><a href="#wrangling">数据整理</a></li>
# <li><a href="#eda">探索性数据分析</a></li>
# <li><a href="#conclusions">结论</a></li>
# </ul>
#
# <a id='intro'></a>
# ## 简介
#
# 这份报告将对影响利润的因素以及评分与流行度之间的关系进行分析。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## 数据整理
#
# > **提示**：在报告的这一部分中载入数据，检查简洁度，然后整理和清理数据集，以便进行分析。请务必将步骤仔细归档，并确定清理决策是否正确。
#
# ### 常规属性

# %%
# 加载数据并打印几行。进行这几项操作，来检查数据
#   类型，以及是否有缺失数据或错误数据的情况。
df = pd.read_csv('tmdb-movies.csv')
print(df.columns)
print(df.head(50))
df.dtypes
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')
#         id    imdb_id  popularity     budget     revenue  \
# 0   135397  tt0369610   32.985763  150000000  1513528810
# 1    76341  tt1392190   28.419936  150000000   378436354
# 2   262500  tt2908446   13.112507  110000000   295238201
# 3   140607  tt2488496   11.173104  200000000  2068178225
# 4   168259  tt2820852    9.335014  190000000  1506249360
# 5   281957  tt1663202    9.110700  135000000   532950503
# 6    87101  tt1340138    8.654359  155000000   440603537
# 7   286217  tt3659388    7.667400  108000000   595380321
# 8   211672  tt2293640    7.404165   74000000  1156730962
# 9   150540  tt2096673    6.326804  175000000   853708609
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
print(df.duplicated().sum())
df.drop_duplicates(inplace = True)
# Out:
# 1

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %% [markdown]
# > **提示**：_不应_在每个 notebook 框 (cell) 中进行太多操作。可以自由创建框，来进行数据探索。在这个项目中，可以在初始 notebook 中进行大量探索性操作。不要求对其进行组织，但请务必仔细阅读备注，理解每个代码框的用途。完成分析之后，你可以创建 notebook 副本，在其中去除多余数据，组织好你的每一步分析，从而形成信息连贯、结构紧密的报告。
#
# > **提示**：请务必向你的读者告知你在调查中采取的步骤。在每个代码框或每组相关代码框后面，用 markdown 框对前面的框中的调查结果向读者进行说明。你需要尽量做到这一点，以便读者更好地理解后续框中的内容。
#
# ### 数据清理（请用更具体的标题来代替该标题。）

# %%
# 由于buget \ revenue 使用adj调整后数值更准确，因此丢弃
# imdb id 与 id作用相同，可删除imdb id

print(df.shape)
drop_list = ['budget', 'revenue', 'imdb_id']
df.drop(drop_list, axis = 1, inplace = True)
print(df.shape)
df.columns
# Out:
# (10865, 21)
# (10865, 18)
# Index(['id', 'popularity', 'original_title', 'cast', 'homepage', 'director',
#        'tagline', 'keywords', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'vote_average',
#        'release_year', 'budget_adj', 'revenue_adj'],
#       dtype='object')

# %% [markdown]
# <a id='eda'></a>
# ## 探索性数据分析
#
# > **提示**在你完成数据整理和清理之后，现在可以进行探索性数据分析了。你需要计算统计值，创建可视化图表，解决你在一开始的简介部分中提出的研究问题。我们推荐你采用系统化方法。一次只探索一个变量，然后探索变量之间的关系。
#
# ###  研究问题1 —— popularity，buget, vote_average与revenue的关系？

# %%
# 将这几个与revenue相关性可能较大的因素单独列出来
new_list = ['popularity','vote_average','budget_adj','revenue_adj']
dfnew_list = pd.DataFrame()
for i in new_list:
    dfnew_list[i] = df[i]
dfnew_list.head()
# Out:
#    popularity  vote_average    budget_adj   revenue_adj
# 0   32.985763           6.5  1.379999e+08  1.392446e+09
# 1   28.419936           7.1  1.379999e+08  3.481613e+08
# 2   13.112507           6.3  1.012000e+08  2.716190e+08
# 3   11.173104           7.5  1.839999e+08  1.902723e+09
# 4    9.335014           7.3  1.747999e+08  1.385749e+09

# %%
# 用describe先对数据进行检查
dfnew_list.describe()
# Out:
#          popularity  vote_average    budget_adj   revenue_adj
# count  10865.000000  10865.000000  1.086500e+04  1.086500e+04
# mean       0.646446      5.975012  1.754989e+07  5.136900e+07
# std        1.000231      0.935138  3.430753e+07  1.446383e+08
# min        0.000065      1.500000  0.000000e+00  0.000000e+00
# 25%        0.207575      5.400000  0.000000e+00  0.000000e+00
# 50%        0.383831      6.000000  0.000000e+00  0.000000e+00
# 75%        0.713857      6.600000  2.085325e+07  3.370173e+07
# max       32.985763      9.200000  4.250000e+08  2.827124e+09

# %%
# 通过散点图实现同时看几个变量之间的关系
pd.plotting.scatter_matrix(dfnew_list, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x107c0d278>,
# ...
#       dtype=object)

# %%
# 从describe和散点图中都能发现数据有异常
# buget和revenue 前25%的数据都是0 
# 估计是空值，进行检查
len(dfnew_list[dfnew_list['budget_adj'] == 0])
# Out:
# 5696

# %%
# 检查revenue
len(dfnew_list[dfnew_list['revenue_adj'] == 0])
# Out:
# 6016

# %%
# 将数值为0的数据去掉，重新建立一个dataframe
dfbudrev = dfnew_list[(dfnew_list['revenue_adj'] != 0)&(dfnew_list['budget_adj'] != 0)]
dfbudrev.shape
# Out:
# (3854, 4)

# %%
# 预算与利润关系并不明显
dfbudrev.plot(x='budget_adj', y='revenue_adj', kind='scatter', alpha=0.3)

# %%
# 分数与利润呈正相关
dfbudrev.plot(x='vote_average', y='revenue_adj', kind='scatter', alpha=0.3)

# %%
# 流行度与利润关系并不明显
dfbudrev.plot(x='popularity', y='revenue_adj', kind='scatter', alpha=0.3);

# %% [markdown]
# ### 研究问题 2 —— genres 与 popularity的关系

# %%
# 每部电影同时属于多个题材，需要简化
# 将题材中第一个种类作为主要题材
# 并且先清理空值
print(df.shape)
df1 = df[df['genres'].notnull()]
print(df1.shape)
df1.head()
# Out:
# (10865, 18)
# (10842, 18)
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# ...

# %%
#将众多电影类型分离
df_clean = df1[df1['genres'].notna()]
df_clean = df_clean.drop('genres', axis=1).join(df_clean['genres'].str.split('|', expand=True).stack().reset_index(level=1, drop=True).rename('genres'))
df_clean.head()
# Out:
#        id  popularity      original_title  \
# 0  135397   32.985763      Jurassic World
# 0  135397   32.985763      Jurassic World
# 0  135397   32.985763      Jurassic World
# 0  135397   32.985763      Jurassic World
# 1   76341   28.419936  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.
# ...

# %%
# 对每一种类型进行统计
genres_count = df_clean['genres'].value_counts()
print(genres_count)
# Out:
# Drama              4760
# Comedy             3793
# Thriller           2907
# Action             2384
# Romance            1712
# Horror             1637
# Adventure          1471
# Crime              1354
# Family             1231
# Science Fiction    1229
# Fantasy             916
# Mystery             810
# Animation           699
# Documentary         520
# Music               408
# History             334
# War                 270
# Foreign             188
# TV Movie            167
# Western             165
# Name: genres, dtype: int64

# %%
len(genres_count)
# Out:
# 20

# %%
genres_count.index
# Out:
# Index(['Drama', 'Comedy', 'Thriller', 'Action', 'Romance', 'Horror',
#        'Adventure', 'Crime', 'Family', 'Science Fiction', 'Fantasy', 'Mystery',
#        'Animation', 'Documentary', 'Music', 'History', 'War', 'Foreign',
#        'TV Movie', 'Western'],
#       dtype='object')

# %%
df_clean.shape[0]
# Out:
# 26955

# %%
plt.bar(genres_count.index, genres_count);

# %%
#plt.figure(16,4)
plt.figure(figsize=(16,4))
plt.bar(genres_count.index, genres_count);

# %%
#plt.figure(16,4)
plt.figure(figsize=(16,4))
plt.bar(genres_count[:10].index, genres_count[:10]);

# %%
genres_count.hist();

# %%
#genres与popularity的关系可视化
df_clean.plot.bar(x = 'genres_count', y = 'dfpopularity',figsize=(12,4))
# Out:
# --------------------------------------------------
# KeyError         Traceback (most recent call last)
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dfpopularity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError         Traceback (most recent call last)
# <ipython-input-27-5b4a9fb8d8d6> in <module>
#       1 #genres与popularity的关系可视化
# ...

# %%
# 观众们大多青睐冒险片和科幻片
df1.groupby(['genres'])['popularity'].mean().nlargest()

# %% [markdown]
# <a id='conclusions'></a>
# ## 结论
#
# > **提示**：最后，你需要总结自己的调查结果。请确保你了解在探索过程中的局限性。如果尚未进行任何统计检验，不要做出任何统计结论。切记不要根据相关关系贸然推导出因果关系！
#
# > **提示**：如果你对自己的研究成果感到满意，应将其副本保存为 HTML 或 PDF 形式。在导出报告之前请检查一遍，确保报告结构完整，信息连贯。应删除所有类似的“提示”引用段，以保持报告中的简洁度。在提交之前，你还需要查看在课程结尾的项目提交页面中的项目审阅规范。
#
# > 如需将报告导出到工作区，你可以运行下面的代码框。如果正确，会返回代码 0，工作区目录下会生成 .html 文件（单击左上角的 jupyter 图标）。也可以通过 **文件** > **下载为** 子菜单下载 html 报告，然后手动上传到工作区目录。完成之后，可以单击右下角的“提交项目”，来提交你的项目。恭喜你！

# %%
# 从两个分析看出，影片分数越高，则利润越大
# 而冒险片和科幻片跟受欢迎
# 分析过程中，尤其是对第一问题进行分析时，清洗数据量大
# 结果的准确性会有所影响

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 255
