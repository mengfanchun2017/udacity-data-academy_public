# %%
import sqlite3
import pandas as pd
cnx = sqlite3.connect('northwind.sqlite3')
cnx.text_factory = bytes
df = pd.read_sql_query("SELECT * FROM Products", cnx)

# %%
df.head(50)
# Out:
#     ProductID                         ProductName  SupplierID  CategoryID  \
# 0           1                             b'Chai'           1           1
# 1           2                            b'Chang'           1           1
# 2           3                    b'Aniseed Syrup'           1           2
# 3           4     b"Chef Anton's Cajun Seasoning"           2           2
# 4           5           b"Chef Anton's Gumbo Mix"           2           2
# 5           6     b"Grandma's Boysenberry Spread"           3           2
# 6           7  b"Uncle Bob's Organic Dried Pears"           3           7
# 7           8       b'Northwoods Cranberry Sauce'           3           2
# 8           9                  b'Mishi Kobe Niku'           4           6
# 9          10                            b'Ikura'           4           8
# 10         11                   b'Queso Cabrales'           5           4
# 11         12        b'Queso Manchego La Pastora'           5           4
# ...
