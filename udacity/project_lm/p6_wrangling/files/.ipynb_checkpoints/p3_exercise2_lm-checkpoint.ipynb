# %% [markdown]
# # /5评估数据/ Assessing
# Use the space below to explore `all_alpha_08.csv` and `all_alpha_18.csv` to answer the quiz questions below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df08 = pd.read_csv('all_alpha_08.txt', sep = '\t')
df18 = pd.read_csv('all_alpha_18.txt', sep = '\t')
# 注意原文件链接为xlsx、zip和txt（不是csv，csv课程中没给出链接）
# 使用read_csv读入，发现没有分列，看样子是tab分割
# 加个 sep = '\t'指定使用tab分割解决
# （mac 遇到奇怪问题下载的文件都很奇怪，可能和单位网有关）

# %%
df08.head(3)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
# 1  8HNXT03.7PKR       SUV                   6          Drv       15      20
# 2  8HNXT02.3DKR       SUV                   7          Drv       17      22
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no
# 2      19        24.1745                    5       no

# %%
# 测试map函数，temp版本
'''
dflist = list(df08.columns)
dflist_lower = []
for i in dflist:
    value = list(map(lambda x: x(i), funcs))
    print(value)
dflist_l = map(lambda x: x.lower(), dflist)
#dflist_lower = dflist(list(df08.columns).lower()
print(dflist)
print(dflist_l)
''';

# %%
# test rename temp
# 官方文档：https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html
## mapper 如果不指定的话，会默认在index上
## 比如下面这个会报错（因为index是int，没法str.lower
# df08.rename(str.lower, inplace = True)
# 方法1: 设置axis = 'columns' 或者 1
dftest1 = df08.rename(str.lower, axis = 1)
print(dftest1.head(3))
# 方法2: 设置 colunms参数，可以直接定义columns要改变的名字
# dfcol = df08.columns
dftest2 = df08.rename(columns = {'Model':'M'})
print(dftest2.head(3))
# Out:
#        model  displ      cyl    trans drive      fuel sales area stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    underhood id veh class air pollution score fe calc appr city mpg hwy mpg  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
# 1  8HNXT03.7PKR       SUV                   6          Drv       15      20
# 2  8HNXT02.3DKR       SUV                   7          Drv       17      22
#
#   cmb mpg  unadj cmb mpg greenhouse gas score smartway
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no
# 2      19        24.1745                    5       no
#            M  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
# 1  8HNXT03.7PKR       SUV                   6          Drv       15      20
# 2  8HNXT02.3DKR       SUV                   7          Drv       17      22
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no
# 2      19        24.1745                    5       no

# %%
df18.head(3)
# Out:
#        Model  Displ  Cyl  Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA ILX    2.4  4.0  AMS-8   2WD  Gasoline          CA  L3ULEV125
# 1  ACURA ILX    2.4  4.0  AMS-8   2WD  Gasoline          FA     T3B125
# 2  ACURA MDX    3.0  6.0  AMS-7   4WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0  California LEV-III ULEV125  JHNXV02.4NH3  small car                    3
# 1      Federal Tier 3 Bin 125  JHNXV02.4NH3  small car                    3
# 2  California LEV-III ULEV125  JHNXV03.08H3  small SUV                    3
#
#   City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay Comb CO2
# 0       25      35      29                     6       No      309
# 1       25      35      29                     6       No      309
# 2       26      27      27                     6       No      330

# %% [markdown]
# 1.每个数据集中的样本数
#
# 2.每个数据集中的列数

# %%
print(df08.shape)
print(df18.shape)
# Out:
# (2404, 18)
# (2648, 18)

# %% [markdown]
# 3.每个数据集中重复的行数

# %%
sum_dup_08 = sum(df08.duplicated())
sum_dup_18 = sum(df18.duplicated())
print(sum_dup_08,sum_dup_18)
# Out:
# 25 0

# %% [markdown]
# 4.列的数据类型

# %%
df08.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales Area               object
# Stnd                     object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score      object
# FE Calc Appr             object
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Unadj Cmb MPG           float64
# Greenhouse Gas Score     object
# SmartWay                 object
# dtype: object

# %% [markdown]
# 5.具有缺失值的特征

# %%
null_list = []
for i in df08.columns:
    if df08[i].isnull().any():
        null_list.append(i)
null_list
# 使用判断把空置输出为一列
# Out:
# ['Cyl',
#  'Trans',
#  'Drive',
#  'FE Calc Appr',
#  'City MPG',
#  'Hwy MPG',
#  'Cmb MPG',
#  'Unadj Cmb MPG',
#  'Greenhouse Gas Score']

# %%
# 使用isnull.sum检查数量
nucheck = df08.isnull().sum()
nucheck
# Out:
# Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales Area                0
# Stnd                      0
# Underhood ID              0
# Veh Class                 0
# Air Pollution Score       0
# FE Calc Appr            199
# City MPG                199
# Hwy MPG                 199
# Cmb MPG                 199
# Unadj Cmb MPG           199
# Greenhouse Gas Score    199
# SmartWay                  0
# dtype: int64

# %%
# 看下占的百分比
round(nucheck/df08.shape[0],3)
# round(float,n) 的作用是把float小数，保留到小数点后n位
# 当然了 nucheck是求出的丢失值的数量，df08.shape[0]是所有项，案例1有讲
# Out:
# Model                   0.000
# Displ                   0.000
# Cyl                     0.083
# Trans                   0.083
# Drive                   0.039
# Fuel                    0.000
# Sales Area              0.000
# Stnd                    0.000
# Underhood ID            0.000
# Veh Class               0.000
# Air Pollution Score     0.000
# FE Calc Appr            0.083
# City MPG                0.083
# Hwy MPG                 0.083
# Cmb MPG                 0.083
# Unadj Cmb MPG           0.083
# Greenhouse Gas Score    0.083
# SmartWay                0.000
# dtype: float64

# %% [markdown]
# 6.每个数据集中特征的非空唯一值的数量

# %%
for i in df08.columns:
    print(i, end = ' : ')
    print(df08[i].nunique())
# 可以使用格式化字符串来更好的显示，略过
# Out:
# Model : 436
# Displ : 47
# Cyl : 8
# Trans : 14
# Drive : 2
# Fuel : 5
# Sales Area : 3
# Stnd : 12
# Underhood ID : 343
# Veh Class : 9
# Air Pollution Score : 13
# FE Calc Appr : 2
# City MPG : 39
# Hwy MPG : 43
# Cmb MPG : 38
# Unadj Cmb MPG : 721
# Greenhouse Gas Score : 20
# SmartWay : 2

# %%
# 这些唯一值都是什么，以及每个的计数

# %%
# 加上value_counts 看下（车型较多有400多种）
# 使用[1:]将车型过滤掉
for i in df08.columns[1:]:
    print('\n', i, ':')
    print(df08[i].value_counts())
# Out:
#  Displ :
# 3.5    194
# 2.4    184
# 2.5    171
# 3.0    158
# 2.0    132
# 3.6    110
# 5.3    108
# 6.0    103
# 3.7     86
# 5.4     81
# 4.0     80
# 4.6     80
# 4.8     74
# 2.3     71
# 2.7     68
# 3.8     62
# 5.7     59
# 4.2     57
# 4.7     45
# 6.2     41
# 1.8     36
# 3.2     34
# 2.2     30
# 5.5     30
# 5.0     29
# 3.3     24
# 1.6     24
# 2.9     24
# 4.3     22
# 5.6     20
# 3.1     18
# 4.4     16
# 3.4     16
# 6.7     14
# 6.8     13
# 1.5     12
# 6.1     12
# 5.9     12
# 2.8     12
# 6.5     10
# 3.9      8
# 4.5      6
# 1.3      6
# 8.4      4
# 5.2      4
# 7.0      2
# 8.0      2
# Name: Displ, dtype: int64
#
#  Cyl :
# (6 cyl)     864
# (4 cyl)     600
# (8 cyl)     533
# (5 cyl)     113
# (12 cyl)     60
# (10 cyl)     29
# (2 cyl)       4
# (16 cyl)      2
# Name: Cyl, dtype: int64
#
#  Trans :
# Auto-L4    502
# Auto-L5    329
# Auto-S6    327
# Man-6      295
# Man-5      269
# Auto-S5    147
# Auto-L6    118
# Auto-AV     86
# Auto-L7     42
# Auto-S4     42
# Auto-S7     22
# Auto-4      10
# S8           8
# Auto-6       8
# Name: Trans, dtype: int64
#
#  Drive :
# 2WD    1525
# 4WD     786
# Name: Drive, dtype: int64
#
#  Fuel :
# Gasoline       2318
# ethanol/gas      72
# diesel           11
# CNG               2
# ethanol           1
# Name: Fuel, dtype: int64
#
#  Sales Area :
# FA    1157
# CA    1084
# FC     163
# Name: Sales Area, dtype: int64
#
#  Stnd :
# B5      990
# L2      556
# U2      428
# B4      125
# B8       95
# HDV      84
# S2       76
# B2       16
# B3       15
# SLEV     11
# B10       6
# LEV       2
# Name: Stnd, dtype: int64
#
#  Underhood ID :
# 8GMXK06.0389    48
# 8GMXT05.3384    46
# 8BMXB03.0N52    46
# 8VVXV02.5U2T    32
# 8BMXV03.0N54    32
# 8ADXV02.0366    28
# 8GMXK06.0396    28
# 8GMXT06.2382    26
# 8FJXB02.5PYH    26
# 8GMXB03.6148    24
# 8GMXV02.4025    24
# 8CRXT03.7NE0    24
# 8FJXB02.5MXG    20
# 8GMXV02.3001    20
# 8CRXB02.4ME0    20
# 8MBXV06.0L2A    20
# 8CRXT05.7PE0    20
# 8PRXV03.4C87    20
# 8VWXV02.5253    20
# 8TYXT03.5BEM    20
# 8PRXV03.8997    20
# 8GMXT03.6151    20
# 8GMXT05.3373    20
# 8VWXV02.5257    20
# 8NSXT04.0G6A    20
# 8CRXT03.7PE0    19
# 8ADXV03.1374    18
# 8TYXT04.0AEM    18
# 8GMXT06.2394    18
# 8GMXT06.0387    16
#                 ..
# 8FMXV02.3VZT     2
# 8ABBV04.4H10     2
# 8TKXV02.0NH1     2
# 8CEXK06.7UXW     2
# 8TYXV04.3AJA     2
# 8BMXT03.0E70     2
# 8MTXV02.0GRG     2
# 8MBXV03.0U2A     2
# 8GMXT05.3376     1
# 8TKXV02.35NN     1
# 8DSXV02.4G6G     1
# 8GMXT02.4123     1
# 8TKXV02.3NF1     1
# 8FMXT05.43HP     1
# 8TKXV02.3NH2     1
# 8GMXT04.2188     1
# 8VWXT05.0375     1
# 8TYXV02.4HX2     1
# 8NSXV02.5G3A     1
# 8GMXT05.3377     1
# 8S3XT05.4IBB     1
# 8GMXT03.9140     1
# 8KMXV02.0LPC     1
# 8FMXT05.44E2     1
# 8HYXV02.0HPC     1
# 8FMXT06.85HR     1
# 8DSXV02.4GRG     1
# 8MBXV03.0BN8     1
# 8GMXT02.4124     1
# 8GMXT02.4135     1
# Name: Underhood ID, Length: 343, dtype: int64
#
#  Veh Class :
# small car          692
# SUV                648
# pickup             350
# midsize car        276
# large car          129
# van                129
# station wagon      123
# minivan             37
# special purpose     20
# Name: Veh Class, dtype: int64
#
#  Air Pollution Score :
# 6      1471
# 7       521
# 2       112
# 3        85
# 9.5      80
# 6/6      32
# 3/3      27
# 9        23
# 1        22
# 8        15
# 7/7      12
# 0         3
# 6/4       1
# Name: Air Pollution Score, dtype: int64
#
#  FE Calc Appr :
# Drv    2175
# 5cy      30
# Name: FE Calc Appr, dtype: int64
#
#  City MPG :
# 17       233
# 16       216
# 15       213
# 20       195
# 19       182
# 18       180
# 14       172
# 13       160
# 12       135
# 21       122
# 22        88
# 23        45
# 24        42
# 11        35
# 10        28
# 11/14     20
# 25        16
# 27        16
# 26        16
# 9         12
# 9/12      10
# 29        10
# 9/14       9
# 9/13       7
# 34         6
# 11/15      6
# 8          6
# 13/18      4
# 28         4
# 10/13      3
# 40         2
# 33         2
# 13/19      2
# 48         2
# 10/14      2
# 35         1
# 12/16      1
# 11/17      1
# 14/18      1
# Name: City MPG, dtype: int64
#
#  Hwy MPG :
# 24       241
# 20       174
# 25       169
# 26       167
# 28       148
# 19       144
# 22       143
# 18       126
# 27       123
# 23       106
# 29        99
# 17        99
# 31        76
# 30        66
# 16        59
# 21        58
# 32        35
# 33        34
# 15        21
# 14/19     14
# 15/20     12
# 34        12
# 35        11
# 14        10
# 12/17      8
# 12/19      7
# 13         6
# 12/16      6
# 36         6
# 45         4
# 13/18      2
# 13/19      2
# 19/25      2
# 13/17      2
# 20/27      2
# 12/18      2
# 37         2
# 16/23      2
# 17/23      1
# 21/29      1
# 19/26      1
# 17/24      1
# 20/28      1
# Name: Hwy MPG, dtype: int64
#
#  Cmb MPG :
# 20       215
# 22       211
# 19       196
# 18       183
# 21       166
# 15       164
# 14       156
# 16       144
# 17       139
# 24       134
# 23       119
# 25        73
# 26        46
# 27        34
# 13        34
# 12        30
# 28        28
# 29        24
# 12/16     20
# 10/15     15
# 11        14
# 10/14     11
# 32         8
# 31         6
# 10         6
# 13/17      4
# 16/22      3
# 34         3
# 15/21      3
# 11/15      3
# 13/18      2
# 42         2
# 46         2
# 30         2
# 12/15      2
# 13/19      1
# 16/21      1
# 14/19      1
# Name: Cmb MPG, dtype: int64
#
#  Unadj Cmb MPG :
# 13.8612    16
# 18.9273    16
# 27.7684    14
# 29.2274    14
# 31.1162    12
# 28.6009    12
# 24.3604    12
# 26.2843    12
# 12.9000    10
# 19.5000    10
# 29.3687    10
# 19.0126    10
# 27.3126    10
# 24.8679     9
# 19.9678     9
# 35.9566     9
# 18.9287     9
# 33.7076     9
# 25.8136     8
# 16.4338     8
# 14.8322     8
# 13.8375     8
# 25.8212     8
# 12.2796     8
# 28.8034     8
# 24.2241     8
# 25.3086     8
# 27.5143     8
# 15.2051     8
# 32.5709     8
#            ..
# 19.2186     1
# 26.5701     1
# 26.0747     1
# 18.3969     1
# 21.8924     1
# 26.0000     1
# 25.8697     1
# 34.6809     1
# 18.9358     1
# 26.9756     1
# 24.4810     1
# 16.1362     1
# 26.8962     1
# 21.6747     1
# 16.5908     1
# 26.8575     1
# 12.9349     1
# 25.1000     1
# 46.7098     1
# 13.7631     1
# 19.4531     1
# 25.8353     1
# 21.1376     1
# 22.5424     1
# 12.7142     1
# 13.2223     1
# 26.1804     1
# 20.4407     1
# 36.7250     1
# 12.8322     1
# Name: Unadj Cmb MPG, Length: 721, dtype: int64
#
#  Greenhouse Gas Score :
# 6      589
# 5      380
# 7      327
# 4      285
# 3      165
# 2      156
# 8      131
# 0       50
# 1       33
# 6/4     24
# 9       19
# 4/3     15
# 4/2     11
# 8/6      4
# 10       4
# 5/3      3
# 7/6      3
# 6/5      3
# 6/3      2
# 7/5      1
# Name: Greenhouse Gas Score, dtype: int64
#
#  SmartWay :
# no     1766
# yes     638
# Name: SmartWay, dtype: int64

# %% [markdown]
# # /6清理列标签/ 清除列标签
# 使用 all_alpha_08.csv 和 all_alpha_18.csv

# %%
#先检查下原有数据
print(df08.shape)
df08.columns
# Out:
# (2404, 18)
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#        'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
# 丢弃多余列
drop_list = ['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG']
df08.drop(drop_list, axis=1, inplace=True)
print(df08.shape)
df08.columns
# Out:
# (2404, 14)
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area',
#        'Veh Class', 'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
drop_list = ['Stnd','Stnd Description','Underhood ID','Comb CO2']
df18.drop(drop_list, axis=1, inplace=True)
print(df18.shape)
df18.columns
# Out:
# (2648, 14)
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert Region',
#        'Veh Class', 'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
# 先检查一下有没有列不同的
df08.columns == df18.columns
# 输出是个boolean的列表，比较直观
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True])

# %%
# 把08列的名字得出来
for i in df08.columns:
    if i not in df18.columns:
        print(i)

# 把18列的名字得出来
for i in df18.columns:
    if i not in df08.columns:
        print(i)
# Out:
# Sales Area
# Cert Region

# %%
# 将08的替换为18的
df08.rename(columns = 
            lambda x: x.replace('Sales Area', 'Cert Region'), 
            inplace = True)
# 这里使用的是lambda x:
# 就是对columns执行后面的操作 x.replace
# 而x.replace的操作是把后面小括弧中的前面替换成后面

# %%
# 还有就是把列中的空格替换成下滑线
# 因为很多处理要对空格判断，不要有比较好
# 全部变为小写是习惯，了解一下吧
df08.rename(columns=lambda x:
             x.strip().lower().replace(" ", "_"),
             inplace=True)
# .strip是去除单词首尾的空格
# .lower是变为小写
# .replace是把小括弧里的做替换
df08.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
# df18 也做一遍，再检查列是否一致
df18.rename(columns=lambda x:
             x.strip().lower().replace(" ", "_"),
             inplace=True)
print(df18.columns)
df08.columns == df18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
# 也可以用这个，比较安静的，因为加了.all()所以只会出一个True或者False
(df08.columns == df18.columns).all()
# Out:
# True

# %%
# 保存数据
df08.to_csv('data_08.csv', index=False)
df18.to_csv('data_18.csv', index=False)

# %% [markdown]
# # /7过滤、丢空、去重/ 过滤、丢弃空值、重复数据删除
# 使用 data_08.csv 和 data_18.csv

# %%
# 按认证区域过滤09
def cleancol(df):
    print(df.shape)
    df['cert_region'].unique()
    df = df.query('cert_region == "CA"')
    print(df.shape)      
    print(df['cert_region'].unique())
    df.drop(['cert_region'],axis=1,inplace=True)
    print(df.shape) 
    return df.info()


cleancol(df18)
cleancol(df08)
# 此cell如果执行多遍会有问题因为已经drop了cert_region
# 少年，要不要使用try/except优化了？
# 另外后面有个报错，怎么优化呢？
# Out:
# (2648, 14)
# (1307, 14)
# ['CA']
# (1307, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1307 entries, 0 to 2646
# Data columns (total 13 columns):
# model                   1307 non-null object
# displ                   1292 non-null float64
# cyl                     1292 non-null float64
# trans                   1307 non-null object
# drive                   1307 non-null object
# fuel                    1307 non-null object
# veh_class               1307 non-null object
# air_pollution_score     1307 non-null int64
# city_mpg                1307 non-null object
# hwy_mpg                 1307 non-null object
# cmb_mpg                 1307 non-null object
# greenhouse_gas_score    1307 non-null int64
# smartway                1307 non-null object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 143.0+ KB
# (2404, 14)
# (1084, 14)
# ['CA']
# (1084, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 2400
# Data columns (total 13 columns):
# model                   1084 non-null object
# displ                   1084 non-null float64
# cyl                     1009 non-null object
# trans                   1009 non-null object
# drive                   1047 non-null object
# fuel                    1084 non-null object
# veh_class               1084 non-null object
# air_pollution_score     1084 non-null object
# city_mpg                1009 non-null object
# hwy_mpg                 1009 non-null object
# cmb_mpg                 1009 non-null object
# greenhouse_gas_score    1009 non-null object
# smartway                1084 non-null object
# dtypes: float64(1), object(12)
# memory usage: 118.6+ KB
# /Users/francis/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# 丢弃含有缺失值的行
# 检查下缺失值
print(df08.isnull().sum())
# 丢弃有缺失的
df08.dropna(inplace = True)
df08.isnull().sum()
# Out:
# model                     0
# displ                     0
# cyl                     199
# trans                   199
# drive                    93
# fuel                      0
# cert_region               0
# veh_class                 0
# air_pollution_score       0
# city_mpg                199
# hwy_mpg                 199
# cmb_mpg                 199
# greenhouse_gas_score    199
# smartway                  0
# dtype: int64
# model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# cert_region             0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
print(df18.isnull().sum())
df18.dropna(inplace = True)
df18.isnull().sum()
# Out:
# model                    0
# displ                   36
# cyl                     36
# trans                    0
# drive                    0
# fuel                     0
# cert_region              0
# veh_class                0
# air_pollution_score      0
# city_mpg                 0
# hwy_mpg                  0
# cmb_mpg                  0
# greenhouse_gas_score     0
# smartway                 0
# dtype: int64
# model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# cert_region             0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
# double check 一下
df08.isnull().sum().any()
# Out:
# False

# %%
df18.isnull().sum().any()
# Out:
# False

# %%
# 重复数据删除
print(df08.duplicated().sum())
df08.drop_duplicates(inplace = True)
print(df08.duplicated().sum())
# Out:
# 63
# 0

# %%
print(df18.duplicated().sum())
df18.drop_duplicates(inplace = True)
print(df18.duplicated().sum())
# Out:
# 22
# 0

# %%
# 保存进度，以便下一段使用
df08.to_csv('data_08b.csv', index=False)
df18.to_csv('data_18b.csv', index=False)
# 建议使用不同的文件名，等都完成后再调优，避免覆盖文件带来的麻烦

# %% [markdown]
# # /8检查数据类型/ Inspecting Data Types
# Use the space below to explore data_08.csv and data_18.csv to answer the quiz questions below regarding datatypes.

# %%
print(df08.head(1))
type(df08.info())
# Out:
#        model  displ      cyl    trans drive      fuel cert_region veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2142 entries, 0 to 2403
# Data columns (total 14 columns):
# model                   2142 non-null object
# displ                   2142 non-null float64
# cyl                     2142 non-null object
# trans                   2142 non-null object
# drive                   2142 non-null object
# fuel                    2142 non-null object
# cert_region             2142 non-null object
# veh_class               2142 non-null object
# air_pollution_score     2142 non-null object
# city_mpg                2142 non-null object
# hwy_mpg                 2142 non-null object
# cmb_mpg                 2142 non-null object
# greenhouse_gas_score    2142 non-null object
# smartway                2142 non-null object
# dtypes: float64(1), object(13)
# memory usage: 251.0+ KB
# NoneType

# %% [markdown]
# - cyl字符串要转换成数字
# - air_polution转成浮点（object是字符串）
# - city_mpg、hwy_mpg、cmb_mpg将字符串转换为浮点型
# - greenhouse_gas_score从字符转为浮点

# %% [markdown]
# # /9修正数据类型第1部分/

# %%
# 使用str的extract检索里面的数字
print(df08['cyl'].value_counts())
df08['cyl'] = df08['cyl'].str.extract('(\d+)').astype(int)
# （\d+)是匹配任意数字的意思，有兴趣的可以看看reg或者回顾week2格式化字符串
print(df08['cyl'].value_counts())
type(df08['cyl'][0])
# Out:
# (6 cyl)     836
# (4 cyl)     582
# (8 cyl)     516
# (5 cyl)     113
# (12 cyl)     60
# (10 cyl)     29
# (2 cyl)       4
# (16 cyl)      2
# Name: cyl, dtype: int64
# 6     836
# 4     582
# 8     516
# 5     113
# 12     60
# 10     29
# 2       4
# 16      2
# Name: cyl, dtype: int64
# numpy.int64

# %%
# cyl18
print(df18['cyl'].value_counts())
df18['cyl'] = df18['cyl'].astype(int)
# 貌似astype不能使用inplace参数
print(df18['cyl'].value_counts())
type(df18['cyl'][0])
# Out:
# 4.0     1210
# 6.0      843
# 8.0      418
# 12.0      51
# 3.0       42
# 10.0      16
# 2.0        4
# 5.0        4
# 16.0       2
# Name: cyl, dtype: int64
# 4     1210
# 6      843
# 8      418
# 12      51
# 3       42
# 10      16
# 5        4
# 2        4
# 16       2
# Name: cyl, dtype: int64
# numpy.int64

# %% [markdown]
# # /10修正数据类型第2部分/

# %%
'''
# air08
type(df08['air_pollution_score'][0])
df08['air_pollution_score'].astype(float, inplace = True)
df08['air_pollution_score'].astype(int, inplace = True)
# 像‘5.0’这样的字符如果使用int转换会报错
# ValueError: invalid literal for int() with base 10:
# 但使用float转换不会报错，详见
# https://stackoverflow.com/questions/1841565/valueerror-invalid-literal-for-int-with-base-10#
type(df08['air_pollution_score'][0])
# 因为有 x/y 这种，所以转换会报错
'''
# Out:
# "\n# air08\ntype(df08['air_pollution_score'][0])\ndf08['air_pollution_score'].astype(float, inplace = True)\ndf08['air_pollution_score'].astype(int, inplace = True)\n# 像‘5.0’这样的字符如果使用int转换会报错\n# ValueError: invalid literal for int() with base 10:\n# 但使用float转换不会报错，详见\n# https://stackoverflow.com/questions/1841565/valueerror-invalid-literal-for-int-with-base-10#\ntype(df08['air_pollution_score'][0])\n# 因为有 x/y 这种，所以转换会报错\n"

# %%
# 找出含有 / 的部分
# 也可以使用query方式
hb_08 = df08[df08['fuel'].str.contains('/')]
print(hb_08.shape)

# 拆分为两列，使用copy否则会修改原数据
# create two copies of the 2008 hybrids dataframe
df1 = hb_08.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_08.copy()  # data on second fuel type of each hybrid vehicle

# 确定要拆分的列
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])
    # lambda对每个带/的进行分割，分别赋值第1个和第2个拆分元素
print(df1.head(3))
# 看下是否成功

dfnewrows = df1.append(df2)
print(df1.shape)
print(dfnewrows.shape)
dfnewrows.head(3)
# 检查数量
# Out:
# (65, 14)
#                         model  displ  cyl    trans drive     fuel cert_region  \
# 316  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol          FC
# 317  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol          FC
# 321  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol          FC
#
#     veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 316       SUV                   7       11      15      12
# 317       SUV                   7       11      14      12
# 321       SUV                   6       11      15      12
#
#     greenhouse_gas_score smartway
# 316                    6       no
# 317                    6       no
# 321                    6       no
# (65, 14)
# (130, 14)
#                         model  displ  cyl    trans drive     fuel cert_region  \
# 316  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol          FC
# 317  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol          FC
# 321  CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol          FC
#
#     veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 316       SUV                   7       11      15      12
# 317       SUV                   7       11      14      12
# 321       SUV                   6       11      15      12
#
#     greenhouse_gas_score smartway
# 316                    6       no
# 317                    6       no
# 321                    6       no

# %%
# 更新df08
print(df08.shape)
print(hb_08.index)
# 检查下要删除的行
df08.drop(hb_08.index, inplace = True)
df08 = df08.append(dfnewrows, ignore_index = True)
# append 没有inplace参数
df08.shape
# Out:
# (2142, 14)
# Int64Index([ 316,  317,  321,  322,  380,  381,  386,  416,  417,  429,  430,
#              437,  438,  473,  474,  478,  479,  487,  488,  490,  491,  512,
#              525,  561,  562,  612,  619,  637,  648,  678,  679,  688,  689,
#              729,  730,  767,  857,  858,  859,  865,  992,  993, 1008, 1009,
#             1038, 1039, 1046, 1047, 1087, 1088, 1092, 1093, 1289, 1290, 1310,
#             1311, 1549, 1550, 1635, 1733, 1734, 1764, 1765, 1808, 1809],
#            dtype='int64')
# (2207, 14)

# %%
# 2018的数据
# air 和 green已经是float格式不用拆分
# 找出含有 / 的部分
# 也可以使用query方式
hb_18 = df18[df18['fuel'].str.contains('/')]
print(hb_18.shape)

# 拆分为两列，使用copy否则会修改原数据
# create two copies of the 2008 hybrids dataframe
df1 = hb_18.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_18.copy()  # data on second fuel type of each hybrid vehicle

# 确定要拆分的列
# columns to split by "/"
split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])
    # lambda对每个带/的进行分割，分别赋值第1个和第2个拆分元素
print(df1.head(3))
# 看下是否成功

dfnewrows = df1.append(df2)
print(df1.shape)
print(dfnewrows.shape)
dfnewrows.head(3)
# 检查数量
# Out:
# (160, 14)
#               model  displ  cyl       trans drive      fuel cert_region  \
# 55   AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline          CA
# 56   AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline          FA
# 171        BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline          CA
#
#      veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 55   small car                    7       34      39      36
# 56   small car                    7       34      39      36
# 171  small car                    3       28      34      30
#
#      greenhouse_gas_score smartway
# 55                     10    Elite
# 56                     10    Elite
# 171                    10      Yes
# (160, 14)
# (320, 14)
#               model  displ  cyl       trans drive      fuel cert_region  \
# 55   AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline          CA
# 56   AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline          FA
# 171        BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline          CA
#
#      veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 55   small car                    7       34      39      36
# 56   small car                    7       34      39      36
# 171  small car                    3       28      34      30
#
#      greenhouse_gas_score smartway
# 55                     10    Elite
# 56                     10    Elite
# 171                    10      Yes

# %%
# 更新df18
print(df18.shape)
print(hb_18.index)
# 检查下要删除的行
df18.drop(hb_18.index, inplace = True)
df18 = df18.append(dfnewrows, ignore_index = True)
# append 没有inplace参数
df18.shape
# Out:
# (2590, 14)
# Int64Index([  55,   56,  171,  172,  223,  224,  225,  226,  255,  256,
#             ...
#             2495, 2496, 2521, 2522, 2614, 2615, 2638, 2639, 2646, 2647],
#            dtype='int64', length=160)
# (2750, 14)

# %%
# 现在可以转换了 08 / 18
df08.air_pollution_score = df08.air_pollution_score.astype(float)
df18.air_pollution_score = df18.air_pollution_score.astype(float)

df08.to_csv('data_08c.csv', index=False)
df18.to_csv('data_18c.csv', index=False)

# %% [markdown]
# # /11 修正数据类型第3部分/ 修正 city_mpg、hwy_mpg、cmb_mpg 数据类型
# 2008 和 2018：将字符串转换成浮点

# %%
# 将 mpg 列转换成浮点
mpg_columns = ['city_mpg','hwy_mpg','cmb_mpg']
for c in mpg_columns:
    df18[c] = df18[c].astype(float)
    df08[c] = df18[c].astype(float)

# %%
# 将 greenhouse转成浮点
df18['greenhouse_gas_score'] = df18['greenhouse_gas_score'].astype(float)
df08['greenhouse_gas_score'] = df08['greenhouse_gas_score'].astype(float)

# %%
df08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# cert_region              object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score    float64
# smartway                 object
# dtype: object

# %%
df18.dtypes
df18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
df08.to_csv('clean_08.csv', index=False)
df18.to_csv('clean_18.csv', index=False)
df18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %% [markdown]
# # /12 使用可视化探索数据/ Exploring with Visuals
# Use clean_08.csv and clean_18.csv

# %%
df08.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
p08=plt.hist(df08['greenhouse_gas_score'],color='r', alpha = 0.5)
p18=plt.hist(df18['greenhouse_gas_score'],color='b', alpha = 0.5)
plt.show()
# 哇偶，可以看出18年的greenhouse_gas_score有所下降！
# 企鹅宝宝，，，

# %%
city=plt.hist(df08['city_mpg'],color='r', alpha = 0.5)
hwy=plt.hist(df08['hwy_mpg'],color='b', alpha = 0.5)
cmb = plt.hist(df08['cmb_mpg'],color='g', alpha = 0.5)
plt.show()
# 从数据可以推断出city是在城市的速度（miles per hour）
# hwy是高速的，cmb是联合的

# %%
p08=plt.hist(df08['air_pollution_score'],color='b')
p18=plt.hist(df18['air_pollution_score'],color='r')

# 也是下降了，不好看
# 这里没有家alpha，没有透明度，一下就记住了对不对

# %% [markdown]
# ### PS：数据的链接地址有所有数据的联合csv下载，有兴趣的来啊！

# %% [markdown]
# # /13 结论和可视展示/ 得出结论
# 使用下列空间来处理数据集clean_08.csv 和clean_18.csv中的以下问题

# %% [markdown]
# ## Q1: 与2008年相比，2018年是否有更多的车型（去重后）使用替代能源？比例增长了多少？
#
# - 这部分feature pdf中没有特殊说明，bing出来：
# - CNG 压缩天然气
# - dissel 柴油
# - Gasoline 汽油
# - ethanol 乙醇
# - gas 天然气
#
# 瞎想的（可以忽悠不懂的）
# 1. CNG是压缩天然气，另外一种是液化天然气LNG（C代表compressed，L代表liquid，LNG可以制造CNG，NG是不经压缩的gas）。后者更环保因为是液态，行驶也更远。但是前一种更加普遍（因为可以使用现在的汽油汽车改装，难道混合动力的都是这个货？）
# 1. 乙醇更环保,天燃气是混合物,里面可能包含一些S,N这些元素.当这些元素燃烧时会产生污染气体.乙醇燃烧的产物是二氧化碳和水.再者乙醇是可再生资源,所以目前有很多国家在汽油用填加乙醇,已减少汽油的使用量。
# 1. 在18年的数据中还有电力汽车（我的特斯拉啊，看着就帅！，，，，这模型还挺重的）马克思，，哦不马斯克的Solar City了解一下。
# 1. 综上所述，由于各年的value不同，我们就分为两个阵营进行比较（谁说要加权来的，你出来，我保证，，，不打死你，，，）Gasoline和diesel作为传统能源，其他都粗暴的归为清洁能源。

# %%
df08.groupby(['fuel']).count()
# Out:
#           model  displ   cyl  trans  drive  cert_region  veh_class  \
# fuel
# CNG           2      2     2      2      2            2          2
# Gasoline   2067   2067  2067   2067   2067         2067       2067
# diesel        7      7     7      7      7            7          7
# ethanol      66     66    66     66     66           66         66
# gas          65     65    65     65     65           65         65
#
#           air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# fuel
# CNG                         2         2        2        2
# Gasoline                 2067      2067     2067     2067
# diesel                      7         7        7        7
# ethanol                    66        66       66       66
# gas                        65        65       65       65
#
#           greenhouse_gas_score  smartway
# fuel
# CNG                          2         2
# Gasoline                  2067      2067
# diesel                       7         7
# ethanol                     66        66
# gas                         65        65

# %%
df18.groupby(['fuel']).count()
# Out:
#              model  displ   cyl  trans  drive  cert_region  veh_class  \
# fuel
# Diesel          62     62    62     62     62           62         62
# Electricity     66     66    66     66     66           66         66
# Ethanol         94     94    94     94     94           94         94
# Gas             94     94    94     94     94           94         94
# Gasoline      2434   2434  2434   2434   2434         2434       2434
#
#              air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# fuel
# Diesel                        62        62       62       62
# Electricity                   66        66       66       66
# Ethanol                       94        94       94       94
# Gas                           94        94       94       94
# Gasoline                    2434      2434     2434     2434
#
#              greenhouse_gas_score  smartway
# fuel
# Diesel                         62        62
# Electricity                    66        66
# Ethanol                        94        94
# Gas                            94        94
# Gasoline                     2434      2434

# %%
# %%timeit

# 使用timeit进行计时比较
# %是计算一句，%%是计算一个cell
# time是计算1遍，timeit可以加参数，默认执行100遍
# https://ipython.org/ipython-doc/3/interactive/magics.html

cleanlist = ['cng', 'ethanol', 'gas', 'electricity']
# 先制定清洁能源的备选

def cleanratio(df):
    cnumber = 0
    fuel_list = list(set(df['fuel'].values))
    
    for i in fuel_list:
        if i.lower() in cleanlist:
            cnumber = cnumber + df[df['fuel'] == i].shape[0]
    return round(cnumber / df.shape[0],4)
    # 使用round控制小数的精度：round（你要显示的数，你要显示的小数位数）
            
cleanratio(df08)
cleanratio(df18)
# 可见从6%增长到了9%
# Out:
# 6.15 ms ± 801 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
# updated Kaido和Leo跑出来的简洁方法
cleanlist = ['cng', 'ethanol', 'gas', 'electricity']
# 先制定清洁能源的备选

def cleanratio2(df):
    # 此处首先将['fuel']中的值都转换为小写
    # 再通过isin进行过滤是否在cleanlist
    # 将过滤出来的做平均值（因为true=1， false=0，所以取mean就是比率了）
    return round(df['fuel'].str.lower().isin(cleanlist).mean())

                 
#print(cleanratio2(df08))
#print(cleanratio2(df18))
# 可见从6%增长到了9%
# Out:
# 158 ns ± 3.27 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
## 从上两个代码看，6.15ms vs 158nm，效率差了40倍！
## 原因是最前面的方法设定了很多中间变量
## 而且还用for做了循环（需要计算n次，计算量为O(n)）

# %% [markdown]
# ## Q2: 各车辆类别（veh_class）在燃料经济性方面的改进（mpg 的增长）是多少？

# %%
# 经过观察，发现cmb在city和hwy之间，应该是经过加权了的，直接比较他
mpgc08 = df08.groupby(['veh_class'])['cmb_mpg'].mean()
# 其实还可以发现value的种类不同，有兴趣规整一下不少年？
mpgc08
# Out:
# veh_class
# SUV              23.922360
# large car        22.827068
# midsize car      23.421245
# minivan          25.743590
# pickup           22.125475
# small car        23.394659
# station wagon    23.081301
# van              23.879310
# Name: cmb_mpg, dtype: float64

# %%
mpgc18 = df18.groupby(['veh_class'])['cmb_mpg'].mean()
mpgc18
# Out:
# veh_class
# large car          24.115789
# midsize car        30.121560
# minivan            27.181818
# pickup             18.120968
# small SUV          24.339744
# small car          25.696429
# special purpose    19.888889
# standard SUV       19.370000
# station wagon      30.000000
# van                15.166667
# Name: cmb_mpg, dtype: float64

# %%
# 因为名字是不同的，直接相减
mpcompare = mpgc18- mpgc08
# 凡事带有NaN的说明在另一个数据里面没有
# 不同名字的不比较，使用dropna处理
mpcompare.dropna(inplace = True)
mpcompare
# Out:
# veh_class
# large car        1.288722
# midsize car      6.700314
# minivan          1.438228
# pickup          -4.004508
# small car        2.301770
# station wagon    6.918699
# van             -8.712644
# Name: cmb_mpg, dtype: float64

# %%
mpcompare.values
# Out:
# array([ 1.2887218 ,  6.70031421,  1.43822844, -4.00450754,  2.30176982,
#         6.91869919, -8.71264368])

# %%
# OK 可以画图鸟
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)

colors = []
for value in mpcompare.values:
    if value >= 0:
        colors.append('g')
    else:
        colors.append('r')
mpcompare.plot(kind = 'bar', alpha = 0.7, color = colors)
# color可以通过输入一个列表指定
# 要想根据条件输出不同color，写个循环先建立好color列表
ax.set_xticklabels(mpcompare.index, fontsize = 12, rotation = 30);
ax.set_ylabel('Change MPG', fontsize = 16)
ax.set_xlabel('Veh Classed', fontsize = 16)
fig.suptitle('Veh MPG Change form 2008 to 2018', fontsize = 24, color = 'red');
# Out:
# Text(0.5,0.98,'Veh MPG Change form 2008 to 2018')

# %% [markdown]
# ## Q3: SmartWay 车辆的特点是什么？ 它们是否随着时间而改变？

# %%
# smartway labels for 2008
df08.smartway.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# get all smartway vehicles in 2008
smart_08 = df08.query('smartway == "yes"')
print(smart_08.info())
smart_08.mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625 entries, 6 to 2066
# Data columns (total 14 columns):
# model                   625 non-null object
# displ                   625 non-null float64
# cyl                     625 non-null int64
# trans                   625 non-null object
# drive                   625 non-null object
# fuel                    625 non-null object
# cert_region             625 non-null object
# veh_class               625 non-null object
# air_pollution_score     625 non-null float64
# city_mpg                625 non-null float64
# hwy_mpg                 625 non-null float64
# cmb_mpg                 625 non-null float64
# greenhouse_gas_score    625 non-null float64
# smartway                625 non-null object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 73.2+ KB
# None
# displ                    2.49232
# cyl                      4.66400
# air_pollution_score      6.99680
# city_mpg                21.08640
# hwy_mpg                 28.26080
# cmb_mpg                 23.76640
# greenhouse_gas_score     7.02720
# dtype: float64

# %%
print(df18.smartway.unique())
smart_18 = df18.query('smartway == "Yes" or smartway == "Elite"')
print(smart_18.info())
smart_18.mean()
# Out:
# ['No' 'Yes' 'Elite']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 422 entries, 57 to 2749
# Data columns (total 14 columns):
# model                   422 non-null object
# displ                   422 non-null float64
# cyl                     422 non-null int64
# trans                   422 non-null object
# drive                   422 non-null object
# fuel                    422 non-null object
# cert_region             422 non-null object
# veh_class               422 non-null object
# air_pollution_score     422 non-null float64
# city_mpg                422 non-null float64
# hwy_mpg                 422 non-null float64
# cmb_mpg                 422 non-null float64
# greenhouse_gas_score    422 non-null float64
# smartway                422 non-null object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 49.5+ KB
# None
# displ                    1.879147
# cyl                      4.071090
# air_pollution_score      5.246445
# city_mpg                38.568720
# hwy_mpg                 43.710900
# cmb_mpg                 40.469194
# greenhouse_gas_score     8.146919
# dtype: float64

# %% [markdown]
# ## Q4: 哪些功能与更好的燃油经济性有关？What features are associated with better fuel economy?
# You can explore trends between cmb_mpg and the other features in this dataset, or filter this dataset like in the previous question and explore the properties of that dataset. For example, you can select all vehicles that have the top 50% fuel economy ratings like this.

# %%
# 这里课程给出的答案好奇怪，等我想想的
top_08 = df08.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  977.000000  977.000000           977.000000  977.000000  977.000000
# mean     3.627124    6.151484             6.325486   25.225179   33.011259
# std      1.282356    1.877275             0.975360    4.807190    4.486190
# min      1.500000    4.000000             1.000000   20.000000   26.000000
# 25%      2.500000    4.000000             6.000000   22.000000   30.000000
# 50%      3.500000    6.000000             6.000000   24.000000   32.000000
# 75%      4.600000    8.000000             7.000000   27.000000   35.000000
# max      7.000000   12.000000             9.500000   57.000000   59.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  977.000000            977.000000
# mean    28.164790              5.032753
# std      4.463705              1.973947
# min     24.000000              0.000000
# 25%     25.000000              4.000000
# 50%     27.000000              5.000000
# 75%     30.000000              6.000000
# max     58.000000             10.000000

# %%
top_18 = df18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe()
# Out:
#              displ          cyl  air_pollution_score     city_mpg  \
# count  1080.000000  1080.000000          1080.000000  1080.000000
# mean      1.978889     4.074074             4.933333    29.712037
# std       0.493440     0.569599             1.857081    15.371140
# min       0.600000     2.000000             1.000000    21.000000
# 25%       1.600000     4.000000             3.000000    23.000000
# 50%       2.000000     4.000000             5.000000    25.000000
# 75%       2.000000     4.000000             7.000000    29.000000
# max       4.000000     6.000000             8.000000   145.000000
#
#            hwy_mpg      cmb_mpg  greenhouse_gas_score
# count  1080.000000  1080.000000           1080.000000
# mean     36.646296    32.310185              6.530556
# std      12.394836    13.970812              1.562712
# min      26.000000    25.000000              4.000000
# 25%      31.000000    26.000000              5.000000
# 50%      33.000000    28.000000              6.000000
# 75%      37.000000    32.000000              7.000000
# max     121.000000   133.000000             10.000000

# %% [markdown]
# ## 最后一个问题！对于 2008 年生产且 2018 年仍在生产中的车型，mpg 有多少改进，哪些车辆的改进最多？
# 这个问题是关于 2008 年以来不断更新换代且 2018 年仍在生产的车型。要回答此问题，我们需要找到两个数据集中都存在的车型，那么先让我们来了解如何将两个数据集合并。

# %%
print(df18.shape)
df18.columns
# Out:
# (2750, 14)
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
print(df08.shape)
print(df08.columns)
df08.columns
# Out:
# (2207, 14)
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
# 需要使用merge将2个数据融合
# 就能根据mode有2个以上的value count来判断是否两个都有了

# %%
df08.rename(
    columns = lambda x: x[:10] + '_2008', inplace = True)
df08.rename(columns={'model_2008':'model'},inplace=True)
len(df08.columns)
df08.columns
# Out:
# Index(['model', 'displ_2008', 'cyl_2008', 'trans_2008', 'drive_2008',
#        'fuel_2008', 'cert_regio_2008', 'veh_class_2008', 'air_pollut_2008',
#        'city_mpg_2008', 'hwy_mpg_2008', 'cmb_mpg_2008', 'greenhouse_2008',
#        'smartway_2008'],
#       dtype='object')

# %%
# 为什么要有个一样的model呢，因为合并时候要有一列相同才好合并么
# merge的说明
df_combined = pd.merge(df08,df18,on=['model'])
df_combined.shape
df_combined
# Out:
#               model  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 1         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 2         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 3         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 4         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 5         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 6         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 7         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 8         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 9         ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 10        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 11        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 12        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 13        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 14        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 15        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 16        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 17        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 18        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 19        ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 20        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 21        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 22        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 23        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 24        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 25        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 26        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 27        ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 28          AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 29          AUDI A3         2.0         4      Man-6        2WD  Gasoline
# ...             ...         ...       ...        ...        ...       ...
# 8614  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8615  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8616  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8617  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8618  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8619  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8620  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8621  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8622  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8623  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8624  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8625  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8626  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8627  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8628  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8629  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8630  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8631  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8632  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8633  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8634  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8635  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8636  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8637  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8638  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8639  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8640  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8641  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8642  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
# 8643  FORD F150 FFV         5.4         8    Auto-L4        4WD       gas
#
#      cert_regio_2008 veh_class_2008  air_pollut_2008  city_mpg_2008   ...     \
# 0                 CA            SUV              7.0           25.0   ...
# 1                 CA            SUV              7.0           25.0   ...
# 2                 CA            SUV              7.0           25.0   ...
# 3                 CA            SUV              7.0           25.0   ...
# 4                 CA            SUV              7.0           25.0   ...
# 5                 CA            SUV              7.0           25.0   ...
# 6                 CA            SUV              7.0           25.0   ...
# 7                 CA            SUV              7.0           25.0   ...
# 8                 CA            SUV              7.0           25.0   ...
# 9                 CA            SUV              7.0           25.0   ...
# 10                FA            SUV              6.0           25.0   ...
# 11                FA            SUV              6.0           25.0   ...
# 12                FA            SUV              6.0           25.0   ...
# 13                FA            SUV              6.0           25.0   ...
# 14                FA            SUV              6.0           25.0   ...
# 15                FA            SUV              6.0           25.0   ...
# 16                FA            SUV              6.0           25.0   ...
# 17                FA            SUV              6.0           25.0   ...
# 18                FA            SUV              6.0           25.0   ...
# 19                FA            SUV              6.0           25.0   ...
# 20                CA            SUV              7.0           26.0   ...
# 21                CA            SUV              7.0           26.0   ...
# 22                CA            SUV              7.0           26.0   ...
# 23                CA            SUV              7.0           26.0   ...
# 24                FA            SUV              6.0           26.0   ...
# 25                FA            SUV              6.0           26.0   ...
# 26                FA            SUV              6.0           26.0   ...
# 27                FA            SUV              6.0           26.0   ...
# 28                CA  station wagon              7.0           20.0   ...
# 29                CA  station wagon              7.0           20.0   ...
# ...              ...            ...              ...            ...   ...
# 8614              FA         pickup              3.0           28.0   ...
# 8615              FA         pickup              3.0           28.0   ...
# 8616              FA         pickup              3.0           28.0   ...
# 8617              FA         pickup              3.0           28.0   ...
# 8618              FA         pickup              3.0           28.0   ...
# 8619              FA         pickup              3.0           28.0   ...
# 8620              FA         pickup              3.0           28.0   ...
# 8621              FA         pickup              3.0           28.0   ...
# 8622              FA         pickup              3.0           28.0   ...
# 8623              FA         pickup              3.0           28.0   ...
# 8624              FA         pickup              3.0           28.0   ...
# 8625              FA         pickup              3.0           28.0   ...
# 8626              FA         pickup              3.0           28.0   ...
# 8627              FA         pickup              3.0           28.0   ...
# 8628              FA         pickup              3.0           28.0   ...
# 8629              FA         pickup              3.0           28.0   ...
# 8630              FA         pickup              3.0           28.0   ...
# 8631              FA         pickup              3.0           28.0   ...
# 8632              FA         pickup              3.0           28.0   ...
# 8633              FA         pickup              3.0           28.0   ...
# 8634              FA         pickup              3.0           28.0   ...
# 8635              FA         pickup              3.0           28.0   ...
# 8636              FA         pickup              3.0           28.0   ...
# 8637              FA         pickup              3.0           28.0   ...
# 8638              FA         pickup              3.0           28.0   ...
# 8639              FA         pickup              3.0           28.0   ...
# 8640              FA         pickup              3.0           28.0   ...
# 8641              FA         pickup              3.0           28.0   ...
# 8642              FA         pickup              3.0           28.0   ...
# 8643              FA         pickup              3.0           28.0   ...
#
#       drive      fuel  cert_region  veh_class  air_pollution_score  city_mpg  \
# 0       4WD  Gasoline           CA  small SUV                  3.0      26.0
# 1       4WD  Gasoline           FA  small SUV                  3.0      26.0
# 2       2WD  Gasoline           CA  small SUV                  3.0      19.0
# 3       2WD  Gasoline           CA  small SUV                  3.0      20.0
# 4       2WD  Gasoline           FA  small SUV                  3.0      19.0
# 5       2WD  Gasoline           FA  small SUV                  3.0      20.0
# 6       4WD  Gasoline           CA  small SUV                  3.0      18.0
# 7       4WD  Gasoline           CA  small SUV                  3.0      19.0
# 8       4WD  Gasoline           FA  small SUV                  3.0      18.0
# 9       4WD  Gasoline           FA  small SUV                  3.0      19.0
# 10      4WD  Gasoline           CA  small SUV                  3.0      26.0
# 11      4WD  Gasoline           FA  small SUV                  3.0      26.0
# 12      2WD  Gasoline           CA  small SUV                  3.0      19.0
# 13      2WD  Gasoline           CA  small SUV                  3.0      20.0
# 14      2WD  Gasoline           FA  small SUV                  3.0      19.0
# 15      2WD  Gasoline           FA  small SUV                  3.0      20.0
# 16      4WD  Gasoline           CA  small SUV                  3.0      18.0
# 17      4WD  Gasoline           CA  small SUV                  3.0      19.0
# 18      4WD  Gasoline           FA  small SUV                  3.0      18.0
# 19      4WD  Gasoline           FA  small SUV                  3.0      19.0
# 20      2WD  Gasoline           FA  small SUV                  3.0      20.0
# 21      2WD  Gasoline           CA  small SUV                  3.0      20.0
# 22      4WD  Gasoline           FA  small SUV                  3.0      19.0
# 23      4WD  Gasoline           CA  small SUV                  3.0      19.0
# 24      2WD  Gasoline           FA  small SUV                  3.0      20.0
# 25      2WD  Gasoline           CA  small SUV                  3.0      20.0
# 26      4WD  Gasoline           FA  small SUV                  3.0      19.0
# 27      4WD  Gasoline           CA  small SUV                  3.0      19.0
# 28      4WD  Gasoline           CA  small car                  7.0      24.0
# 29      4WD  Gasoline           FA  small car                  7.0      24.0
# ...     ...       ...          ...        ...                  ...       ...
# 8614    4WD   Ethanol           CA     pickup                  5.0      13.0
# 8615    4WD   Ethanol           CA     pickup                  5.0      14.0
# 8616    4WD   Ethanol           FA     pickup                  5.0      13.0
# 8617    4WD   Ethanol           FA     pickup                  5.0      14.0
# 8618    2WD   Ethanol           CA     pickup                  3.0      12.0
# 8619    2WD   Ethanol           CA     pickup                  3.0      12.0
# 8620    2WD   Ethanol           FA     pickup                  3.0      12.0
# 8621    2WD   Ethanol           FA     pickup                  3.0      12.0
# 8622    4WD   Ethanol           CA     pickup                  3.0      11.0
# 8623    4WD   Ethanol           CA     pickup                  3.0      12.0
# 8624    4WD   Ethanol           CA     pickup                  3.0      12.0
# 8625    4WD   Ethanol           FA     pickup                  3.0      11.0
# 8626    4WD   Ethanol           FA     pickup                  3.0      12.0
# 8627    4WD   Ethanol           FA     pickup                  3.0      12.0
# 8628    2WD       Gas           CA     pickup                  5.0      20.0
# 8629    2WD       Gas           FA     pickup                  5.0      20.0
# 8630    4WD       Gas           CA     pickup                  5.0      18.0
# 8631    4WD       Gas           CA     pickup                  5.0      17.0
# 8632    4WD       Gas           FA     pickup                  5.0      18.0
# 8633    4WD       Gas           FA     pickup                  5.0      17.0
# 8634    2WD       Gas           CA     pickup                  3.0      16.0
# 8635    2WD       Gas           CA     pickup                  3.0      17.0
# 8636    2WD       Gas           FA     pickup                  3.0      16.0
# 8637    2WD       Gas           FA     pickup                  3.0      17.0
# 8638    4WD       Gas           CA     pickup                  3.0      15.0
# 8639    4WD       Gas           CA     pickup                  3.0      16.0
# 8640    4WD       Gas           CA     pickup                  3.0      16.0
# 8641    4WD       Gas           FA     pickup                  3.0      15.0
# 8642    4WD       Gas           FA     pickup                  3.0      16.0
# 8643    4WD       Gas           FA     pickup                  3.0      16.0
#
#      hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0       27.0    27.0                  6.0       No
# 1       27.0    27.0                  6.0       No
# 2       27.0    22.0                  4.0       No
# 3       27.0    23.0                  5.0       No
# 4       27.0    22.0                  4.0       No
# 5       27.0    23.0                  5.0       No
# 6       26.0    21.0                  4.0       No
# 7       26.0    22.0                  4.0       No
# 8       26.0    21.0                  4.0       No
# 9       26.0    22.0                  4.0       No
# 10      27.0    27.0                  6.0       No
# 11      27.0    27.0                  6.0       No
# 12      27.0    22.0                  4.0       No
# 13      27.0    23.0                  5.0       No
# 14      27.0    22.0                  4.0       No
# 15      27.0    23.0                  5.0       No
# 16      26.0    21.0                  4.0       No
# 17      26.0    22.0                  4.0       No
# 18      26.0    21.0                  4.0       No
# 19      26.0    22.0                  4.0       No
# 20      28.0    23.0                  5.0       No
# 21      28.0    23.0                  5.0       No
# 22      27.0    22.0                  4.0       No
# 23      27.0    22.0                  4.0       No
# 24      28.0    23.0                  5.0       No
# 25      28.0    23.0                  5.0       No
# 26      27.0    22.0                  4.0       No
# 27      27.0    22.0                  4.0       No
# 28      31.0    27.0                  6.0       No
# 29      31.0    27.0                  6.0       No
# ...      ...     ...                  ...      ...
# 8614    17.0    15.0                  4.0       No
# 8615    17.0    15.0                  3.0       No
# 8616    17.0    15.0                  4.0       No
# 8617    17.0    15.0                  3.0       No
# 8618    17.0    14.0                  3.0       No
# 8619    17.0    14.0                  3.0       No
# 8620    17.0    14.0                  3.0       No
# 8621    17.0    14.0                  3.0       No
# 8622    14.0    13.0                  3.0       No
# 8623    15.0    13.0                  3.0       No
# 8624    15.0    13.0                  3.0       No
# 8625    14.0    13.0                  3.0       No
# 8626    15.0    13.0                  3.0       No
# 8627    15.0    13.0                  3.0       No
# 8628    25.0    22.0                  4.0       No
# 8629    25.0    22.0                  4.0       No
# 8630    23.0    20.0                  4.0       No
# 8631    22.0    19.0                  3.0       No
# 8632    23.0    20.0                  4.0       No
# 8633    22.0    19.0                  3.0       No
# 8634    20.0    17.0                  3.0       No
# 8635    23.0    19.0                  3.0       No
# 8636    20.0    17.0                  3.0       No
# 8637    23.0    19.0                  3.0       No
# 8638    19.0    17.0                  3.0       No
# 8639    20.0    17.0                  3.0       No
# 8640    22.0    18.0                  3.0       No
# 8641    19.0    17.0                  3.0       No
# 8642    20.0    17.0                  3.0       No
# 8643    22.0    18.0                  3.0       No
#
# [8644 rows x 27 columns]

# %%
mpg2018 = df_combined.groupby('model')['city_mpg'].mean()
mpg2018
# Out:
# model
# ACURA MDX                   20.400000
# ACURA RDX                   19.500000
# AUDI A3                     25.000000
# AUDI A4                     24.000000
# AUDI A6                     22.333333
# AUDI A8 L                   17.500000
# AUDI Q7                     19.000000
# AUDI R8                     14.000000
# AUDI S4                     21.000000
# AUDI S5                     21.000000
# AUDI S6                     16.000000
# AUDI S8                     14.000000
# AUDI TT Coupe               23.000000
# AUDI TT Roadster            23.000000
# BMW 750i                    16.500000
# BMW Alpina B7               16.000000
# BMW M5                      15.000000
# BMW M6 Convertible          14.500000
# BUICK Enclave               17.500000
# CADILLAC CTS                19.600000
# CADILLAC Escalade           14.000000
# CHEVROLET Colorado          18.875000
# CHEVROLET Corvette          14.750000
# CHEVROLET Equinox           25.000000
# CHEVROLET Impala            18.250000
# CHEVROLET Malibu            31.250000
# CHEVROLET Silverado 15      15.055556
# CHEVROLET Suburban 1500     14.166667
# CHEVROLET Tahoe 1500        14.375000
# CHRYSLER 300                16.714286
#                               ...
# PORSCHE Boxster             21.500000
# PORSCHE Boxster S           20.500000
# PORSCHE Cayenne             18.000000
# PORSCHE Cayenne S           17.000000
# PORSCHE Cayenne Turbo       14.000000
# PORSCHE Cayman              21.500000
# PORSCHE Cayman S            20.500000
# ROLLS-ROYCE Phantom         12.000000
# SUBARU Forester             23.666667
# SUBARU Impreza              26.000000
# SUBARU Legacy               22.500000
# TOYOTA 4Runner              17.000000
# TOYOTA Avalon               21.000000
# TOYOTA Camry                25.500000
# TOYOTA Corolla              27.666667
# TOYOTA Highlander           19.750000
# TOYOTA Highlander Hybrid    29.000000
# TOYOTA Land Cruiser         13.000000
# TOYOTA Prius                54.000000
# TOYOTA RAV4                 22.500000
# TOYOTA Sequoia              13.000000
# TOYOTA Sienna               18.500000
# TOYOTA Tacoma               18.333333
# TOYOTA Tundra               13.750000
# TOYOTA Yaris                30.000000
# VOLKSWAGEN GTI              24.500000
# VOLKSWAGEN Jetta            26.000000
# VOLKSWAGEN Passat           22.000000
# VOLVO S60                   23.000000
# VOLVO XC 90                 30.600000
# Name: city_mpg, Length: 127, dtype: float64

# %%
mpg2008 = df_combined.groupby('model')['city_mpg_2008'].mean()
mpg2008
# Out:
# model
# ACURA MDX                   25.000000
# ACURA RDX                   26.000000
# AUDI A3                     21.333333
# AUDI A4                     18.875000
# AUDI A6                     24.000000
# AUDI A8 L                   24.750000
# AUDI Q7                     24.000000
# AUDI R8                     24.000000
# AUDI S4                     18.500000
# AUDI S5                     19.000000
# AUDI S6                     16.500000
# AUDI S8                     14.000000
# AUDI TT Coupe               14.833333
# AUDI TT Roadster            17.500000
# BMW 750i                    20.500000
# BMW Alpina B7               20.000000
# BMW M5                      21.000000
# BMW M6 Convertible          24.000000
# BUICK Enclave               19.500000
# CADILLAC CTS                20.200000
# CADILLAC Escalade           16.250000
# CHEVROLET Colorado          21.066667
# CHEVROLET Corvette          22.000000
# CHEVROLET Equinox           21.750000
# CHEVROLET Impala            17.250000
# CHEVROLET Malibu            19.333333
# CHEVROLET Silverado 15      15.916667
# CHEVROLET Suburban 1500     15.571429
# CHEVROLET Tahoe 1500        18.000000
# CHRYSLER 300                18.083333
#                               ...
# PORSCHE Boxster             20.166667
# PORSCHE Boxster S           16.500000
# PORSCHE Cayenne             27.500000
# PORSCHE Cayenne S           28.000000
# PORSCHE Cayenne Turbo       28.000000
# PORSCHE Cayman              25.666667
# PORSCHE Cayman S            24.500000
# ROLLS-ROYCE Phantom         28.000000
# SUBARU Forester             21.300000
# SUBARU Impreza              23.250000
# SUBARU Legacy               18.928571
# TOYOTA 4Runner              25.000000
# TOYOTA Avalon               21.000000
# TOYOTA Camry                23.285714
# TOYOTA Corolla              22.000000
# TOYOTA Highlander           21.750000
# TOYOTA Highlander Hybrid    22.500000
# TOYOTA Land Cruiser         23.500000
# TOYOTA Prius                25.000000
# TOYOTA RAV4                 26.750000
# TOYOTA Sequoia              22.875000
# TOYOTA Sienna               21.750000
# TOYOTA Tacoma               18.928571
# TOYOTA Tundra               16.300000
# TOYOTA Yaris                21.000000
# VOLKSWAGEN GTI              19.250000
# VOLKSWAGEN Jetta            26.666667
# VOLKSWAGEN Passat           28.875000
# VOLVO S60                   18.000000
# VOLVO XC 90                 20.500000
# Name: city_mpg_2008, Length: 127, dtype: float64

# %%
# 两个数据都有了，那么我们画图好了吧
# 太多了！根据题目，需要研究的是那些改动最多
# 那么先计算一下吧
mpgchange = mpg2018 - mpg2008
# 我们来排序一下(还有sort_index)
top10 = round(mpgchange.sort_values()[:10],2)
top10
# Out:
# model
# JEEP Wrangler           -25.12
# ROLLS-ROYCE Phantom     -16.00
# LEXUS LX 570            -15.00
# PORSCHE Cayenne Turbo   -14.00
# PORSCHE Cayenne S       -11.00
# TOYOTA Land Cruiser     -10.50
# AUDI R8                 -10.00
# TOYOTA Sequoia           -9.88
# PORSCHE Cayenne          -9.50
# BMW M6 Convertible       -9.50
# dtype: float64

# %%
# 我们来检查下数据
print(mpgchange['JEEP Wrangler'])
print(mpg2008['JEEP Wrangler'])
print(mpg2018['JEEP Wrangler'])
# Out:
# -25.125
# 42.375
# 17.25

# %%
last10 = round(mpgchange.sort_values(ascending = False)[:10],2)
last10
# Out:
# model
# TOYOTA Prius        29.00
# HYUNDAI Accent      13.00
# HONDA Accord        12.50
# HONDA Fit           12.17
# CHEVROLET Malibu    11.92
# VOLVO XC 90         10.10
# HONDA CR-V           9.75
# MAZDA MX-5           9.33
# NISSAN Sentra        9.25
# TOYOTA Yaris         9.00
# dtype: float64

# %% [markdown]
# ### 接下来就可以吧top10和last10画图了，此处自己动手试试吧！
