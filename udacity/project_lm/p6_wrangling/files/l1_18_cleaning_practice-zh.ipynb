# %% [markdown]
# # 清除示例 II
# 我们先练习癌症数据缺失值和重复值的处理。

# %%
# 读入 `cancer_data.csv`
import pandas as pd
df = pd.read_csv('cancer_data.csv')
# 用 info() 检查哪些列有缺失值
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                        569 non-null int64
# diagnosis                 569 non-null object
# radius_mean               569 non-null float64
# texture_mean              548 non-null float64
# perimeter_mean            569 non-null float64
# area_mean                 569 non-null float64
# smoothness_mean           521 non-null float64
# compactness_mean          569 non-null float64
# concavity_mean            569 non-null float64
# concave_points_mean       569 non-null float64
# symmetry_mean             504 non-null float64
# fractal_dimension_mean    569 non-null float64
# radius_SE                 569 non-null float64
# texture_SE                548 non-null float64
# perimeter_SE              569 non-null float64
# area_SE                   569 non-null float64
# smoothness_SE             521 non-null float64
# compactness_SE            569 non-null float64
# ...

# %%
# 扩展2：用均值填充缺失值
# # 使用循环将除了前2列之外的进行均值填充处理
# # 第一列是用户id，第二列是诊断评级（所以不用使用平均值填充，没有意义）
for i in df.columns[2:]:
# 这里做个循环，循环的范围是df数据中的所有数据，除了前面说的第一列和第二列
# [2:] 的意思是从第3列开始到最后一列
    # 使用df.columns遍历列
    # 2: 表示的是从第2列到最后一列（排除了0、1列）
    df[i].fillna(df[i].mean(), inplace = True)
    # # 使用上节的方法完成填充
# 用 info() 确认修改
df.info()
# 这一次就可以看到所有列的飞空数字是一样的了（info显示每列后面的是非空数据）
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                        569 non-null int64
# diagnosis                 569 non-null object
# radius_mean               569 non-null float64
# texture_mean              569 non-null float64
# perimeter_mean            569 non-null float64
# area_mean                 569 non-null float64
# smoothness_mean           569 non-null float64
# compactness_mean          569 non-null float64
# concavity_mean            569 non-null float64
# concave_points_mean       569 non-null float64
# symmetry_mean             569 non-null float64
# fractal_dimension_mean    569 non-null float64
# radius_SE                 569 non-null float64
# texture_SE                569 non-null float64
# perimeter_SE              569 non-null float64
# area_SE                   569 non-null float64
# smoothness_SE             569 non-null float64
# compactness_SE            569 non-null float64
# ...

# %%
# 检查数据中的重复
df_dup = df[df.duplicated()]
df_dup
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 202    852552         M        16.65         21.38          110.00      904.6
# 325  89511502         B        12.67         17.30           81.25      489.9
# 345    898677         B        10.26         14.71           66.20      321.6
# 489   9113846         B        12.27         29.97           77.42      465.4
# 558    925277         B        14.59         22.68           96.39      657.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 202          0.11210           0.14570         0.15250              0.09170
# 325          0.10280           0.07664         0.03193              0.02107
# 345          0.09882           0.09159         0.03581              0.02037
# 489          0.07699           0.03398         0.00000              0.00000
# 558          0.08473           0.13300         0.10290              0.03736
#
# ...

# %%
# 丢弃重复
df_new = df.drop(df_duplicated.index)

# %%
# 再次检查数据中的重复，确认修改
df_new[df_new.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave_points_mean, symmetry_mean, fractal_dimension_mean, radius_SE, texture_SE, perimeter_SE, area_SE, smoothness_SE, compactness_SE, concavity_SE, concave_points_SE, symmetry_SE, fractal_dimension_SE, radius_max, texture_max, perimeter_max, area_max, smoothness_max, compactness_max, concavity_max, concave_points_max, symmetry_max, fractal_dimension_max]
# Index: []
#
# [0 rows x 32 columns]

# %%
# 还可以使用 df.drop_duplicates
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html
df.drop_duplicates(inplace = True)
# 注意如果给这个赋值，会因为对象是object无法进行一些操作

# %%
df.shape, df_new.shape
# 注意以上两个完全相同（两种方法都OK）
# Out:
# ((564, 32), (564, 32))

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 564 entries, 0 to 568
# Data columns (total 32 columns):
# id                        564 non-null int64
# diagnosis                 564 non-null object
# radius_mean               564 non-null float64
# texture_mean              564 non-null float64
# perimeter_mean            564 non-null float64
# area_mean                 564 non-null float64
# smoothness_mean           564 non-null float64
# compactness_mean          564 non-null float64
# concavity_mean            564 non-null float64
# concave_points_mean       564 non-null float64
# symmetry_mean             564 non-null float64
# fractal_dimension_mean    564 non-null float64
# radius_SE                 564 non-null float64
# texture_SE                564 non-null float64
# perimeter_SE              564 non-null float64
# area_SE                   564 non-null float64
# smoothness_SE             564 non-null float64
# compactness_SE            564 non-null float64
# ...

# %%
# 列的数据类型变化.astype()
# 一般来讲，dataframe会根据读入的数据进行自动识别
df_new['radius_max'] = df_new['radius_max'].astype('str')
df_new.info()
# 注意看 radius_max 的类型已经变为 object 了
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 564 entries, 0 to 568
# Data columns (total 32 columns):
# id                        564 non-null int64
# diagnosis                 564 non-null object
# radius_mean               564 non-null float64
# texture_mean              564 non-null float64
# perimeter_mean            564 non-null float64
# area_mean                 564 non-null float64
# smoothness_mean           564 non-null float64
# compactness_mean          564 non-null float64
# concavity_mean            564 non-null float64
# concave_points_mean       564 non-null float64
# symmetry_mean             564 non-null float64
# fractal_dimension_mean    564 non-null float64
# radius_SE                 564 non-null float64
# texture_SE                564 non-null float64
# perimeter_SE              564 non-null float64
# area_SE                   564 non-null float64
# smoothness_SE             564 non-null float64
# compactness_SE            564 non-null float64
# ...

# %% [markdown]
# ## 重命名列
# 由于之前修改了数据集，使其仅包括肿瘤特征的均值，因此每个特征末尾好像不需要 "_mean" 。而且，稍后输入分析还要多耗费时间。我们现在想一些要分配给列的新标签。

# %%
# 从列名称中移除 "_mean"
new_labels = []
for col in df.columns:
    if '_mean' in col:
        new_labels.append(col[:-5])  # 不包括最后 6 个字符
    else:
        new_labels.append(col)

# 列的新标签
new_labels
# Out:
# ['id',
#  'diagnosis',
#  'radius',
#  'texture',
#  'perimeter',
#  'area',
#  'smoothness',
#  'compactness',
#  'concavity',
#  'concave_points',
#  'symmetry',
#  'fractal_dimension',
#  'radius_SE',
#  'texture_SE',
#  'perimeter_SE',
#  'area_SE',
#  'smoothness_SE',
#  'compactness_SE',
#  'concavity_SE',
#  'concave_points_SE',
#  'symmetry_SE',
#  'fractal_dimension_SE',
#  'radius_max',
#  'texture_max',
#  'perimeter_max',
#  'area_max',
#  'smoothness_max',
#  'compactness_max',
#  'concavity_max',
#  'concave_points_max',
#  'symmetry_max',
#  'fractal_dimension_max']

# %%
# 为数据框中的列分配新标签
df.columns = new_labels

# 显示数据框的前几行，确认更改
df.head()
# Out:
#          id diagnosis  radius    texture  perimeter    area  smoothness  \
# 0    842302         M   17.99  19.293431     122.80  1001.0    0.118400
# 1    842517         M   20.57  17.770000     132.90  1326.0    0.084740
# 2  84300903         M   19.69  21.250000     130.00  1203.0    0.109600
# 3  84348301         M   11.42  20.380000      77.58   386.1    0.096087
# 4  84358402         M   20.29  14.340000     135.10  1297.0    0.100300
#
#    compactness  concavity  concave_points          ...            radius_max  \
# 0      0.27760     0.3001         0.14710          ...                 25.38
# 1      0.07864     0.0869         0.07017          ...                 24.99
# 2      0.15990     0.1974         0.12790          ...                 23.57
# 3      0.28390     0.2414         0.10520          ...                 14.91
# 4      0.13280     0.1980         0.10430          ...                 22.54
#
# ...

# %%
# 将其保存，供稍后使用
df.to_csv('cancer_data_edited.csv', index=False)
