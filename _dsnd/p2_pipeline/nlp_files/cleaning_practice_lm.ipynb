# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"
#
# **Note: All solution notebooks can be found by clicking on the Jupyter icon on the top left of this workspace.**

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.
#
# You may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text.

# %%
# import statements
import requests
from bs4 import BeautifulSoup

# %%
# fetch web page
r = requests.get("https://www.udacity.com/courses/all")

# %%
# display text from web page
print(r.text)
# Out:
# <!DOCTYPE html><html><head>
#   <meta charset="utf-8">
#   <script type="text/javascript" class="ng-star-inserted">window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"219146787",sa:1}</script><meta name="newrelic">
#   <title>优达学城课程分类_在线视频课程-优达学城(Udacity)官网</title>
#   <base href="/"><link rel="preload" href="runtime.03ff3c4f12f4dbb360d9.js" as="script"><link rel="preload" href="polyfills.9df7b5bcbc8dce800eac.js" as="script"><link rel="preload" href="scripts.523a55dc1e2a83cc6e5f.js" as="script"><link rel="preload" href="main.8a58d76983cd258f4b70.js" as="script">
#
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <link rel="icon" type="image/x-icon" href="favicon.ico">
#   <link rel="dns-prefetch" href="https://geode.udacity.com">
#   <link rel="dns-prefetch" href="https://sgmt.udacity.com">
#   <link rel="dns-prefetch" href="https://classroom.udacity.com">
#   <!-- inject:js -->
#   <script src="assets/vendor/segment-9cf306f49d.js" async="" data-analytics-bootstrap=""></script>
#   <!-- endinject -->
# <link rel="stylesheet" href="styles.018e28351bc7e5cb825f.css"><link rel="stylesheet" name="ng-shared-styles" href="/assets/styles/styles.shared.49d8862c78.css"><meta property="og:title" content="优达学城课程分类_在线视频课程-优达学城(Udacity)官网"><meta name="twitter:title" content="优达学城课程分类_在线视频课程-优达学城(Udacity)官网"><meta property="og:image" content="https://d20vrrgs8k4bvw.cloudfront.net/images/open-graph/udacity.png"><meta property="og:image:alt" content="Udacity logo"><meta name="twitter:site" property="twitter:site" content="@udacity"><meta name="twitter:creator" property="twitter:creator" content="@udacity"><meta name="twitter:card" property="twitter:card" content="summary_large_image"><meta property="og:type" content="website"><meta name="apple-itunes-app" property="apple-itunes-app" content="app-id=819700933"><meta name="description" property="description" content="优达学城 (Udacity)全部课程目录，为您提供优达学城课程分类、在线视频课程等信息。想要学习编程开发、人工智能技术、机器学习技术、无人驾驶汽车或飞行汽车技术，尽在优达学城 (Udacity)官网"><meta property="og:locale" content="zh-CN"><meta property="og:description" content="优达学城 (Udacity)全部课程目录，为您提供优达学城课程分类、在线视频课程等信息。想要学习编程开发、人工智能技术、机器学习技术、无人驾驶汽车或飞行汽车技术，尽在优达学城 (Udacity)官网"><meta name="twitter:description" content="优达学城 (Udacity)全部课程目录，为您提供优达学城课程分类、在线视频课程等信息。想要学习编程开发、人工智能技术、机器学习技术、无人驾驶汽车或飞行汽车技术，尽在优达学城 (Udacity)官网"><meta name="keywords" property="keywords" content="优达学城课程分类，在线视频课程"><link rel="alternate" hreflang="en" href="https://www.udacity.com/courses/all"><link rel="alternate" hreflang="en-IN" href="https://in.udacity.comundefined/all"><link rel="alternate" hreflang="zh-CN" href="https://cn.udacity.com/courses/all"><link rel="alternate" hreflang="en-AT" href="https://eu.udacity.com/courses/all"><link rel="alternate" hreflang="en-ES" href="https://eu.udacity.com/courses/all"><link rel="alternate" hreflang="en-FR" href="https://eu.udacity.com/courses/all"><link rel="alternate" hreflang="en-IE" href="https://eu.udacity.com/courses/all"><link rel="alternate" hreflang="en-IT" href="https://eu.udacity.com/courses/all"></head>
# <body>
#
# <!-- START: Debug Grid Guidelines -->
# <!-- WARNING: Never update this to GIT -->
# <!-- REQUIRES: enable main[.sandbox.scss|.scss] debug section -->
# <!--<div class="grid-helper">-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--</div>-->
# <!-- END: Debug Grid Guidelines -->
#
# <ir-root _nghost-sc0="" ng-version="7.2.15" class="page-cn page-courses page-courses-all"><ir-nav-mobile _ngcontent-sc0="" _nghost-sc1="" class="mobile-nav__inactive"><a _ngcontent-sc1="" class="logo-link" irhybridlink="/" title="Udacity" href="/"><div _ngcontent-sc1="" class="logo-wordmark"><svg _ngcontent-sc1="" alt="Udacity" height="30" viewBox="0 0 180 30" width="180"><g _ngcontent-sc1="" fill="none" fill-rule="evenodd"><path _ngcontent-sc1="" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 纳米学位&quot;,
#                 &quot;cta_message&quot;: &quot;纳米学位&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://cn.udacity.com/nanodegree" class="ng-star-inserted"> 纳米学位 </a><!----></li><!----><li _ngcontent-sc1="" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" title="所有课程" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 所有课程&quot;,
#                 &quot;cta_message&quot;: &quot;所有课程&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://cn.udacity.com/courses/all" class="ng-star-inserted"> 所有课程 </a><!----></li><!----><li _ngcontent-sc1="" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" title="企业业务" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 企业业务&quot;,
#                 &quot;cta_message&quot;: &quot;企业业务&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://cn.udacity.com/business" class="ng-star-inserted"> 企业业务 </a><!----></li><!----><li _ngcontent-sc1="" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" title="邀请红包" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 邀请红包&quot;,
#                 &quot;cta_message&quot;: &quot;邀请红包&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://cn.udacity.com/referral" class="ng-star-inserted"> 邀请红包 </a><!----></li><!----><li _ngcontent-sc1="" id="signin" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" class="blue ng-star-inserted" title="登录" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 登录&quot;,
#                 &quot;cta_message&quot;: &quot;登录&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://auth.udacity.com/sign-up"> 登录 </a><!----></li><!----><li _ngcontent-sc1="" id="signup" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" class="turquoise ng-star-inserted" title="注册" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - 注册&quot;,
#                 &quot;cta_message&quot;: &quot;注册&quot;,
-0.813 0.148-1.256 0.222 1.773-4.728 2.733-9.825 2.733-15.218v-52.155l23.639-13.666v49.864c-0.073 2.29-0.295 4.432-0.664 6.501z" fill="#1ca7d4" id="mark"></path><path _ngcontent-sc4="" d="m295.37 157.28c0 4.728-3.915 8.569-9.308 8.569s-9.16-3.841-9.16-8.569v-16.917h-2.807v16.991c0 6.058 4.728 11.007 12.041 11.007s12.115-4.949 12.115-11.007v-16.991h-2.807l-0.074 16.917zm30.214-16.917h-8.939v27.702h8.865c8.274 0 13.814-5.097 13.814-13.888 0.074-8.643-5.467-13.814-13.74-13.814zm-0.296 25.191h-5.836v-22.679h5.836c6.722 0 11.229 3.989 11.229 11.302 0.074 7.314-4.433 11.377-11.229 11.377zm79.339 0.369c-6.501 0-11.155-5.319-11.155-11.893 0-6.501 4.654-11.45 11.081-11.45 5.171 0 8.348 3.029 8.348 3.029l1.477-1.995s-3.324-3.546-9.899-3.546c-7.83 0-13.814 6.058-13.814 14.036s5.836 14.405 13.962 14.405c6.796 0 10.49-4.285 10.49-4.285l-1.551-1.921c0-0.074-3.398 3.62-8.939 3.62zm28.441 2.142h2.807v-27.702h-2.807v27.702zm19.207-25.19h9.973v25.191h2.807v-25.191h9.973v-2.512h-22.679v2.512h-0.074zm55.7-2.512-8.791 12.706h-0.074l-8.865-12.706h-3.177l10.638 15.735v11.893h2.807v-11.893l10.49-15.735h-3.028zm-144.57 0-11.229 27.702h2.955l2.955-7.387 12.484-2.586 3.989 9.899h2.955l-11.229-27.702h-2.881v0.074zm-3.989 17.212 5.467-13.445h0.074l4.654 11.302-10.195 2.143z" fill="#2d3c49" id="wordmark-en"></path><line _ngcontent-sc4="" id="stroke-cn" stroke="#7a94a9" stroke-miterlimit="10" x1="274.32" x2="510.71" y1="121.08" y2="121.08"></line><g _ngcontent-sc4="" fill="#2d3c49" id="wordmark-c ...
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 选课指南&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="https://cn.udacity.com/pathfinder/page/hp.html"> 选课指南 </a><!----><!----><!----><a _ngcontent-sc4="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="纳米学位" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 纳米学位&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="https://cn.udacity.com/nanodegree"> 纳米学位 </a><!----><!----><!----><a _ngcontent-sc4="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="所有课程" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 所有课程&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="https://cn.udacity.com/courses/all"> 所有课程 </a><!----><!----><!----><a _ngcontent-sc4="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="企业业务" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 企业业务&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="https://cn.udacity.com/business"> 企业业务 </a><!----><!----><!----><a _ngcontent-sc4="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="邀请红包" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 邀请红包&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="https://cn.udacity.com/referral"> 邀请红包 </a><!----><!----><div _ngcontent-sc4="" class="speech-bubble ng-star-inserted"></div><div _ngcontent-sc4="" class="button button--navigation divider"></div><!----><a _ngcontent-sc4="" data-analytics-event="Navbar Link Clicked" style="display:inline" class="ng-star-inserted button button--navigation button--turquoise" title="免费注册 | 登录" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - 免费注册 | 登录&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_destination&quot;: &quot;self&quot;,
#                 &quot;cta_location&quot;: &quot;Homepage&quot;
#               }" href="https://auth.udacity.com/sign-up"> 免费注册 | 登录 </a></div><!----><div _ngcontent-sc4="" class="enterprise-landing ng-star-inserted"><!----></div><!----><!----><!----></nav></div></header></div><ir-modal _ngcontent-sc4="" _nghost-sc12="" class="ng-tns-c12-1"><div _ngcontent-sc12="" class="wrapper modal--height-vh"><!----><!----><!----><!----><!----><!----></div><!----></ir-modal><!----></ir-header><ir-notification-cn _ngcontent-sc0="" _nghost-sc5=""><ir-notification _ngcontent-sc5="" class="hidden-md-down ng-tns-c14-2" id="notify-verification" _nghost-sc14="" hidden=""><div _ngcontent-sc14="" class="banner-container ng-trigger ng-trigger-shrinkUpAnimation" style=""><div _ngcontent-sc14="" class="banner"><div _ngcontent-sc5="" class="info"><div _ngcontent-sc5="" class="info-qr-code"><span _ngcontent-sc5=""><ir-wechat-binding-qrcode _ngcontent-sc5="" _nghost-sc15=""><!----><!----><canvas _ngcontent-sc15="" id="qrcode-canvas" class="ng-star-inserted" style=""></canvas><!----></ir-wechat-binding-qrcode></span></div><div _ngcontent-sc5=""><p _ngcontent-sc5="">扫码绑定微信，及时获得限时优惠通知</p><p _ngcontent-sc5="">随时掌握硅谷新课动态，成长快人一步！</p></div></div><!----><button _ngcontent-sc14="" class="close-btn ng-tns-c14-2 ng-star-inserted" style=""><svg _ngcontent-sc14="" class="ng-tns-c14-2" height="13" viewBox="0 0 12 13" width="12"><g _ngcontent-sc14="" class="ng-tns-c14-2" fill="#FFF" fill-rule="evenodd" id="close-icon"><path _ngcontent-sc14="" class="ng-tns-c14-2" d="M10.596.49l1.414 1.414L1.404 12.51-.01 11.096z"></path><path _ngcontent-sc14="" class="ng-tns-c14-2" d="M-.01 1.904L1.404.49 12.01 11.096l-1.414 1.414z"></path></g></svg></button></div></div></ir-notification><ir-modal _ngcontent-sc5="" id="service-modal" _nghost-sc12="" class="ng-tns-c12-3"><div _ngcontent-sc12="" class="wrapper"><!----><!----><!----><!----><!----><!----></div><!----></ir-modal></ir-notification-cn><router-outlet _ngcontent-sc0=""></router-outlet><ir-course-catalog-old _nghost-sc247="" class="ng-star-inserted"><!----><section _ngcontent-sc247=""><div _ngcontent-sc247="" class="contain"><ir-experiment _ngcontent-sc247=""><!----><!----><div _ngcontent-sc247="" class="row row-gap-medium ng-star-inserted"><div _ngcontent-sc247="" class="col-sm-6"><h1 _ngcontent-sc247="" class="h-slim-top">课程目录</h1></div><div _ngcontent-sc247="" class="col-sm-6 adjust-search"><input _ngcontent-sc247="" placeholder="" type="text" value="" class="ng-untouched ng-pristine ng-valid"></div></div><!----></ir-experiment><div _ngcontent-sc247="" class="row row-gap-medium"><ir-experiment _ngcontent-sc247=""><div _ngcontent-sc247="" class="col-sm-3 filter-col"><!----><!----><div _ngcontent-sc247="" class="filter-group ng-star-inserted" style="order:0;"><h4 _ngcontent-sc247="" class="filter-header">类别</h4><!----><!----><p _ngcontent-sc247="" class="form-control-static ng-star-inserted"><a _ngcontent-sc247="" class="track-link selected" routerlinkactive="selected" href="/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7">全部课程</a></p><!----><p _ngcontent-sc247="" class="form-control-static ng-star-inserted"><a _ngcontent-sc247="" class="track-link" routerlinkactive="selected" href="/courses/skill-up?udacityAgentHeader=Iridium-Circle-Build-1d9c7">专项提升</a></p><!----><p _ngcontent-sc247="" class="form-control-static ng-star-inserted"><a _ngcontent-sc247="" class="track-link" routerlinkactive="selected" href="/courses/artificial-intelligence?udacityAgentHeader=Iridium-Circle-Build-1d9c7">人工智能/无人驾驶</a></p><!----><p _ngcontent-sc247="" class="form-control-static ng-star-inserted"><a _ngcontent-sc247="" class="track-link" routerlinkactive="selected" href="/courses/machine-learning-deep-learning?udacityAgentHeader=Iridium-Circle-Build-1d9c7">机器学习/深度学习</a></p><!----><p _ngcontent-sc247="" class="form-control-static ng-star-inserted"><a _ngcontent-sc247="" class="track-link" routerlinkactive="selected" href="/courses/data-analytics?udacityAgentHeader=Iridium-Circle-Build-1d9c7">数据分析</a></p ...
# Students will learn how to use header files, control flow, functions, classes.</span></div><!----></div></div><div _ngcontent-sc247="" class="course-summary-card row row-gap-medium ng-star-inserted"><div _ngcontent-sc247="" class="col-sm-3"><!----><img _ngcontent-sc247="" class="course-thumb img-responsive img-bordered center-block ng-star-inserted" height="170" width="290" src="https://s3.cn-north-1.amazonaws.com.cn/static-assets/course-catalog/ud595_thumbnail.jpg" alt="Linux 命令行基础"><!----><!----></div><div _ngcontent-sc247="" class="col-sm-9 course-text"><div _ngcontent-sc247="" class="row"><div _ngcontent-sc247="" class="col-sm-8"><h3 _ngcontent-sc247="" class="h-slim"><a _ngcontent-sc247="" href="/course/linux-command-line-basics--ud595"> Linux 命令行基础</a><span _ngcontent-sc247="" class="badges"><!----></span></h3></div><div _ngcontent-sc247="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-sc247="" class="caption text-right ng-star-inserted"><span _ngcontent-sc247="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-beginner" classname="icon-level course-info-bar-icon icon-level-beginner"></span><span _ngcontent-sc247="" class="capitalize" data-course-level-label="">初级</span></span></div></div><div _ngcontent-sc247=""><!----><span _ngcontent-sc247="" class="ng-star-inserted">了解 Linux 命令行界面</span></div><!----></div></div><div _ngcontent-sc247="" class="course-summary-card row row-gap-medium ng-star-inserted"><div _ngcontent-sc247="" class="col-sm-3"><!----><img _ngcontent-sc247="" class="course-thumb img-responsive img-bordered center-block ng-star-inserted" height="170" width="290" src="https://s3.cn-north-1.amazonaws.com.cn/static-assets/course-catalog/ud359_thumbnail.jpg" alt="数据科学入门"><!----><!----></div><div _ngcontent-sc247="" class="col-sm-9 course-text"><div _ngcontent-sc247="" class="row"><div _ngcontent-sc247="" class="col-sm-8"><h3 _ngcontent-sc247="" class="h-slim"><a _ngcontent-sc247="" href="/course/intro-to-data-science--ud359"> 数据科学入门</a><span _ngcontent-sc247="" class="badges"><!----></span></h3></div><div _ngcontent-sc247="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-sc247="" class="caption text-right ng-star-inserted"><span _ngcontent-sc247="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" classname="icon-level course-info-bar-icon icon-level-intermediate"></span><span _ngcontent-sc247="" class="capitalize" data-course-level-label="">中级</span></span></div></div><div _ngcontent-sc247=""><!----><span _ngcontent-sc247="" class="ng-star-inserted">数据科学家都在做什么？在这门课程中，我们将调查数据科学领域中的重要主题，让你了解成为一个数据科学家的必要技能！</span></div><!----></div></div><div _ngcontent-sc247="" class="course-summary-card row row-gap-medium ng-star-inserted"><div _ngcontent-sc247="" class="col-sm-3"><!----><img _ngcontent-sc247="" class="course-thumb img-responsive img-bordered center-block ng-star-inserted" height="170" width="290" src="https://s3.cn-north-1.amazonaws.com.cn/static-assets/course-catalog/ud615_thumbnail.jpg" alt="使用 Kubernetes 进行可扩展微服务"><!----><!----></div><div _ngcontent-sc247="" class="col-sm-9 course-text"><div _ngcontent-sc247="" class="row"><div _ngcontent-sc247="" class="col-sm-8"><h3 _ngcontent-sc247="" class="h-slim"><a _ngcontent-sc247="" href="/course/scalable-microservices-with-kubernetes--ud615"> 使用 Kubernetes 进行可扩展微服务</a><span _ngcontent-sc247="" class="badges"><!----></span></h3></div><div _ngcontent-sc247="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-sc247="" class="caption text-right ng-star-inserted"><span _ngcontent-sc247="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" classname="icon-level course-info-bar-icon icon-level-intermediate"></span><span _ngcontent-sc247="" class="capitalize" data-course-level-label="">中级</span></span></div></div><div _ngcontent-sc247=""><!----><span _ngcontent-sc247="" class="ng-star-inserted">本课程旨在指导你如何使用 Kubernetes 管理应用容器。</span></div><!----><p _ngconten ...
#     <defs>
#         <linearGradient x1="50%" y1="99.7555012%" x2="50%" y2="0%" id="linearGradient-1">
#             <stop stop-color="#74CD2F" offset="0%"></stop>
#             <stop stop-color="#74CD2F" offset="3%"></stop>
#             <stop stop-color="#9EEE69" offset="96%"></stop>
#             <stop stop-color="#9EEE69" offset="100%"></stop>
#         </linearGradient>
#         <linearGradient x1="50%" y1="100%" x2="50%" y2="0%" id="linearGradient-2">
#             <stop stop-color="#E4E8E9" offset="0%"></stop>
#             <stop stop-color="#DADDE1" offset="0%"></stop>
#             <stop stop-color="#E3E6E9" offset="42%"></stop>
#             <stop stop-color="#F7F9FB" offset="100%"></stop>
#         </linearGradient>
#     </defs>
#     <g id="Artboard" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
#         <g id="画板-1" transform="translate(2.000000, 5.000000)">
#             <path d="M0,9.75 C0.091327201,12.6688973 1.57948018,15.3661745 4,17 C4.20241416,17.1457717 4.32167402,17.3805645 4.32,17.63 C4.3315014,17.7129365 4.3315014,17.7970635 4.32,17.88 L3.8,19.88 C3.76820714,19.9704113 3.7480453,20.0644999 3.74,20.16 C3.74,20.3753911 3.91460895,20.55 4.13,20.55 C4.20825673,20.5466645 4.28420451,20.5224993 4.35,20.48 L6.85,19 C7.0367537,18.8854145 7.25091941,18.8232373 7.47,18.82 C7.58271818,18.8033007 7.69728182,18.8033007 7.81,18.82 C9.03915037,19.1719291 10.31146,19.3503217 11.59,19.35 C17.99,19.35 23.18,15.03 23.18,9.7 C23.18,4.37 18,0.1 11.59,0.1 C5.18,0.1 0,4.42 0,9.75" id="Path" fill="url(#linearGradient-1)"></path>
#             <path d="M12.7,16.92 C12.7,21.36 17.02,24.92 22.35,24.92 C23.4153746,24.9208537 24.4756372,24.7727536 25.5,24.48 C25.7722855,24.4528383 26.0466198,24.5049271 26.29,24.63 L28.4,25.85 C28.4564271,25.8874772 28.5222831,25.9082739 28.59,25.91 C28.7667311,25.91 28.91,25.7667311 28.91,25.59 C28.9202547,25.5103286 28.9202547,25.4296714 28.91,25.35 L28.48,23.73 C28.4713052,23.6636168 28.4713052,23.5963832 28.48,23.53 C28.465583,23.3285142 28.547135,23.132048 28.7,23 C30.7158598,21.6238571 31.9445112,19.36016 32,16.92 C32,12.48 27.68,8.92 22.35,8.92 C17.02,8.92 12.7,12.52 12.7,16.92" id="_剪贴路径_3" fill="url(#linearGradient-2)"></path>
# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.
#
# Again, you may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text. **Alternatively,** you can run the following two lines right before running `soup.get_text()`:
#
# ```python
# for script in soup(["script", "style"]):
#     script.decompose()
# ```
# Read more about this [here](https://stackoverflow.com/questions/22799990/beatifulsoup4-get-text-still-has-javascript).

# %%
soup = BeautifulSoup(r.text, "lxml")

for script in soup(["script", "style"]):
    script.decompose()

print(soup.get_text())
# 报错 lxml 的话需要安装 lxml
# Out:
# 优达学城课程分类_在线视频课程-优达学城(Udacity)官网
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  选课指南  纳米学位  所有课程  企业业务  邀请红包  登录  注册  选课指南  纳米学位  所有课程  企业业务  邀请红包  免费注册 | 登录 扫码绑定微信，及时获得限时优惠通知随时掌握硅谷新课动态，成长快人一步！课程目录类别全部课程专项提升人工智能/无人驾驶机器学习/深度学习数据分析网站开发云计算VR/ARAndroid/iOS非技术类佐治亚理工学院计算机科学硕士类型纳米学位单项课程课程难度初级中级高级预估完成时间1个月以下1-3个月3个月以上 机器学习云部署 (英)高级快速掌握如何将机器学习模型部署在云端 Java 开发工程师 (英)初级学习主流后端语言，开发硅谷企业级应用，迈出成为后端工程师第一步 AI 产品经理 (英)初级驱动 AI 产品商业化落地，用 AI 为业务赋能，成为炙手可热稀缺人才。合作企业 Figure Eight  数据挖掘 求职直通班中级从数据分析、机器学习开始，掌握推荐系统和大数据计算框架 Spark 等核心技能，通过学习、项目、拓展、案例和求职辅导，系统完善对接职场需求，一站式直达职业目标合作企业 Tableau kaggle Starbucks IBM Watson Bertelsmann  市场营销分析 (英)初级掌握市场营销所需的基本数据技能，使用 Google Analytics 和 Data Studio 呈现你的结论 传感器融合 (英)高级和梅赛德斯-奔驰学习，成为掌握无人驾驶、物联网、机器人开发核心技术的抢手工程师。合作企业 Mercedes  数据洞察与说服技巧 (英)中级掌握数据可视化呈现商业洞察，练就用数据影响决策的说服技巧。合作企业 Tableau  云计算软件开发 (英)中级学习在 AWS 上构建全栈应用，并使用 Kubernetes 和 Serverless 框架分发采用微服务的应用，成为炙手可热的云计算软件开发工程师。 云计算 DevOps (英)中级学习在 AWS 上通过代码部署基础设施和应用，构建 CI/CD 管道，以及使用 Kubernetes 和其他现代工具运维化微服务，成为一名抢手的云计算 DevOps 工程师。 AI 求职直通班中级一站掌握机器学习、深度学习、CV、NLP 等 AI 核心技能，覆盖金融风控、计算机视觉、自然语言处理、数据挖掘、计算广告、语音识别六大热门领域，高性价比对接职场需求 C++ 程序设计 (英)中级全面提升面向对象编程能力，成为 C++ 程序设计的专家。 数据结构与算法 (英)中级精选 100+ 道面试真题，挑战数据结构与算法习题，获得详细项目审阅反馈，轻松应对求职面试和工作挑战。 Python 编程入门初级零基础开始，10 周掌握硅谷流行的强大编程语言。 28 天入门 Python初级从零开始掌握编程思维，用 Python 编写爬虫、处理数据，提升工作效率。 高频算法面试题精讲初级ACM 金牌得主亲授，4周掌握高频算法面试解题思路，立即购课，享299元尝鲜价！ Python 人工智能入门初级零基础入门 AI 领域，系统掌握 Python 及机器学习基础技术，挑战工业级实战项目 数据分析（入门）初级一站式入门 Python 和 SQL 两大主流数据分析工具，掌握数据清洗、探索性分析、可视化等基础分析技能 数据工程师 (英)高级学习大数据相关技能，开启数据工程师的职业道路。学习使用 Postgres、Cassandra、Spark 和 Airflow，构建实用数据架构，为数据工程师工作做好准备。合作企业 Insight  商业数据分析初级学会使用 Excel 和 SQL 做数据库查询和调用，并使用 Tableau 搭建可视化面板，让你为企业带来更多价值 AI 量化投资 (英)中级学习量化金融基础知识，掌握 AI 量化交易算法，收集处理市场真实数据，完成你的首个人工智能金融项目。合作企业 WorldQuant  无人驾驶入门中级初识未来驾驶，学习工业和科技变革的前沿技术合作企业 Baidu  数据分析（进阶）中级深入学习数据清洗、探索性分析和可视化，使用 Python、R、SQL 和 Tableau，成为硅谷认可的专业数据分析师 机器学习工程师中级机器学习标志着计算机科学、数据分析、软件工程和人工智能领域内的重大技术突破。AlphaGo 战胜人类围棋冠军、人脸识别、大数据挖掘，都和机器学习密切相关。这个项目将教你如何成为一名机器学习工程师，并将预测模型应用于金融、医疗、教育等领域内的大数据处理。合作企业 亚马逊 Web 服务 kaggle  无人驾驶工程师 (英)高级学习并掌握由世界科技巨头无人驾驶研究团队认可的知识和技能，为正式进入无人驾驶开发领域做好准备。合作企业 Mercedes Benz Nvidia Uber ATG 滴滴出行 BMW McLaren  数据科学家 (英)高级实战由行业知名企业设计的真实数据科学项目，获取专业导师的指导，完善你的个人作品集，实现数据科学家职业晋升！合作企业 Bertelsmann Figure Eight IBM Watson Insight Kaggle Starbucks  机器人开发 (英)高级你将学习机器人开发基础知识，如机器人操作系统（ROS）、Gazebo、定位、感知、SLAM、导航和路径规划，并有机会应用所学技术，在模拟环境中构建机器人解决方案。 计算机视觉高级本课程将帮助你掌握机器人和自动化技术背后的计算机视觉核心技能。编写程序分析图像，实现特征提取，并使用深度学习模型识别对象。合作企业 Affectiva Nvidia DLI  自然语言处理高级IBM、百度、Google、科大讯飞等知名企业正在使用 NLP 技术改变世界。加入课程，用真实世界数据搭建、训练你的模型，加入这场变革！合作企业 Amazon Alexa IBM Watson  区块链开发 (英)中级5 个月掌握区块链区块链基础知识、数字身份、区块链数据及私链搭建、区块链网页服务、区块链智能合约，掌握高级区块链技术，成为行业抢手人才！ 数字营销 (英)初级了解整体营销框架，掌握内容营销、互联网广告平台营销、邮件营销、SEO 等互联网营销技术，获得行业专家的实战经验，成为数字营销人才。合作企业 Google Facebook Hootsuite HubSpot MailChimp  微信小程序开发中级学 Udacity x 微信官方合作课程，把握 10 亿用户微信生态先机合作企业 Wechat  深度强化学习 (英)高级深度强化学习驱动 AI 产业突飞猛进，掌握其背后的技术，并开始将其运用于电子游戏和机器人学等众多领域。合作企业 Unity NVIDIA Deep Learning Institute  飞行汽车开发 (英)高级了解无人机原理，用代码驱动真正的无人机，获得打造复杂飞行汽车系统必备的专业技能，成为抢手人才精英！合作企业 DJI  深度学习中级通过充满活力的课程内容，硅谷优质实战项目以及来自专业辅导，快速入门深度学习领域，为成为人工智能工程师、无人驾驶工程师、机器人工程师打好基础。合作企业 Facebook  前端开发入门初级学习网页开发的基本原理和应用知识，完成一系列实战项目，为成为一名前端工程师打下基础！合作企业 Google Github AT&T  前端开发进阶中级进一步夯实你的前端开发高级技能，完成一系列实战项目，成为一名独当一面的前端工程师！合作企业 Google Github AT&T  全栈开发 (英)中级学习 Python、HTML、CSS、开发者工具和关系数据库，并学习后端开发知识及更高级的前端开发应用，并进行配置服务器，毕业后你将成为硅谷水平的全栈工程师！合作企业 Google 亚马逊 Web 服务 Github AT&T  React 开发 (英)中级世界知名企业 Facebook、 Netflix、Airbnb 等都在使用 React 框架。在这个纳米学位中，学习 React 基础知识、React 与 Redux，以及 React Native 专属课程，成为网页开发抢手人才。 安全与隐私 AI高级学习使用隐私数据集训练模型所需的必要工具，成为更抢手的数据科学家和 AI 从业人员。合作企业 Facebook AI  App 增长——从效果衡量到创意管理中级跟随来自 Udacity 和 Google 的数字营销专家，学习 App 效果衡量与创意素材管理，掌握 App 广告的精髓。合作企业 Google  无人驾驶第一课：从 Apollo 起步初级学习无人驾驶核心概念，掌握高精度地图、定位、感知、预测、规划与控制，接触前沿 Apollo 平台！合作企业 Baidu Apollo  深度学习工具 TensorFlow 入门中级这门课程由 Google 和优达学城（Udacity）共同开发，向软件开发者介绍如何使用 TensorFlow 构建深度学习应用。合作企业 TensorFlow  微信小程序基础：天气应用初级学 Udacity x 微信 权威课程，独立设计、搭建体验丰富的小程序。合作企业 Wechat  微信小程序基础：商城应用中级学 Udacity x 微信 权威课程，独立设计、搭建体验丰富的小程序。合作企业 Wechat  Android 基础：用户界面初级在这门课中，你将学习如何使用 XML 在 Android 中设计一个界面！ Android 应用开发中级开发一个接入云端的 Android 应用，并学习移动开发和 Android 开发的工具、原理和推荐方案。在开发自己的项目时，这些你都会 ...
# Students will learn how to use header files, control flow, functions, classes. Linux 命令行基础初级了解 Linux 命令行界面 数据科学入门中级数据科学家都在做什么？在这门课程中，我们将调查数据科学领域中的重要主题，让你了解成为一个数据科学家的必要技能！ 使用 Kubernetes 进行可扩展微服务中级本课程旨在指导你如何使用 Kubernetes 管理应用容器。合作企业 Google  移动开发中的 UX 设计初级这是一门是为研发人员开设的设计课程。在这门课中，你将学习 UX 设计技巧，设计用户喜爱的5星移动应用。合作企业 Google  Hadoop 和 MapReduce 入门中级此课程较为简短，你将从中了解 MapReduce 和 Apache Hadoop 的基本原理，开始理解大数据在现实世界中的意义！合作企业 Cloudera  关系数据库入门中级关系数据库是非常强大的工具，广泛用于各个行业。你将学习 SQL 基础知识以及如何将 Python 代码与关系数据库相关联。 Swift 入门初级学习用于构建 iOS 应用的 Apple 编程语言—— Swift。先从基础知识开始，然后逐步完成各种 Swift 挑战。 机器人人工智能高级学习如何编程开发一个无人驾驶车的主要构成系统。学习主题包括概率推论、规划和搜索、定位、跟踪和控制。合作企业 佐治亚理工学院  计算机视觉概论中级这门课程将带你走进计算机视觉的的世界，教授基础知识、应用方法和机器学习分类。合作企业 佐治亚理工学院  用 Git 进行版本控制初级学习如何使用 Git，这个每名开发者都需要掌握的流行版本控制系统。 GitHub 协作初级学习如何与其他开发者一起在 GitHub 上协作。 周末学 Firebase: Android中级This course will teach you when and why to choose Firebase as a backend for your Android application.合作企业 Google  操作系统概论中级操作系统概论介绍了基本的操作系统抽象化、机制及实现。合作企业 佐治亚理工学院  全栈基础中级通过使用迭代开发过程全新创建你自己的 Web 应用，了解后端 Web 开发的基本原理。合作企业 亚马逊 Web 服务  计算机网络中级这门高级计算机网络课程将介绍计算机网络领域的常用工具和新概念。合作企业 佐治亚理工学院  在 Android 应用中使用材料设计中级学习定义了 Android 视觉语言的材料设计原则，并把它运用到你的应用上。合作企业 Google  设计 RESTful API中级创建和保护一个后端服务器，并提供用户友好的 RESTful API。 强化学习高级更深入地学习机器学习，成为强化学习研究社区中的一份子。合作企业 佐治亚理工学院  Kotlin for Android Developers高级Take an Android app in Java and convert it to Kotlin, learning key features of the Kotlin programming language along the way. 使用高级分析技术解决问题初级使用 Alteryx 更好地了解数据分析和相关的分析框架。合作企业 Alteryx  网站性能优化中级通过用 Chrome 开发者工具来实验性地测量和优化网站速度，学习浏览器是如何将 HTML、CSS 和 JavaScript 转化为网页的。合作企业 Google  用 Swift 进行 iOS 应用开发入门中级学习构建 iPhone 应用，迈出成为 iOS 工程师的第一步。 Web 开发者的网络入门初级你每天都在使用互联网，来了解互联网的原理吧！ HTML5 Canvas初级学习如何使用 HTML5 Canvas 创建和编辑图片，甚至动画。 软件测试中级学习如何捕获漏洞和破坏软件，并了解可以帮助你构建更好的软件的各种测试方法。 编程语言中级这是一门编程语言基础入门课程，将介绍如何有效处理字符串、语句和程序结构等概念。 VR 入门初级了解虚拟现实 (VR) 的历史和基础知识，迈出你成为一名虚拟现实开发人员的第一步！ 软件开发流程中级这门课程将探索需求工程、架构和设计、测试和维护以及软件质量。合作企业 佐治亚理工学院  日常物品设计入门初级此课程将带你认识设计在当今世界中的作用，并为你提供在生活中做出更好设计决定所需要的见解。 AJAX 入门中级在使用来自 Google 街景、《纽约时报》和维基百科的数据构建 Web 应用的过程中，学习如何发送异步请求。 用 Gradle 构建 Android 和 Java高级用构建工具 Gradle 构建更具规模、更优质的 Android 应用和 Java 应用。合作企业 Google Gradle  软件架构及设计中级学习大型软件系统分析和设计中涉及的原理和概念。合作企业 佐治亚理工学院  网站易用性高级在这门课程里，你将亲身体验如何使网络应用具有无障碍功能。你将理解用户何时需要无障碍功能，为何需要。然后你将深入学习“如何”实现无障碍性。合作企业 Google  响应式图片中级学习如何让图片成为响应式设计工作流程的一部分。合作企业 Google  心理学入门初级了解心理学概念和原理，认识人类思维和行为。合作企业 圣何塞州立大学  后端入门中级 交互式 3D 图形中级此课程将教授 3D 计算机图形的原理：网格、变换、照明、动画，以及使交互式 3D 应用程序在浏览器中运行。合作企业 Autodesk  离线网络应用中级学习如何使用 Service Workers 和 IndexedDB 开发离线优先的网络应用。合作企业 Google  计算机程序设计高级学习如何对问题建模，并使用 Python 的一些高级功能提升性能。 理论计算机科学入门中级学习理论计算机科学的基础知识。了解这些知识对解决复杂的计算难题有何影响。 DevOps 入门高级了解 DevOps 发展状况、工作流程，并探索目前用来支持可扩展软件部署的系统。合作企业 Nutanix  信息安全入门中级合作企业 佐治亚理工学院  如何开发 iOS 应用高级学习应用构建过程，将你的想法变成应用，并发布到 App Store 上！ 物理入门初级探访意大利，荷兰和英国物理学中的著名发现的发生地点，学习物理学基础知识。 学习 Swift 编程语言语法中级本课程重点介绍 Swift 编程语言的语法，完成此课程后，你将能够应用 Swift 基础要素来构建 iOS 应用。 统计学初级我们生活的这个时代充斥着各种信息。你将学习如何运用统计学知识理解这些信息，并作出决策。合作企业 圣何塞州立大学  应用密码学高级从用信用卡付款到使用电话，密码学广泛地存在于我们的日常生活之中。学习在计算领域中制造和破解谜题。 Swift 进阶初级Get a quick practical introduction to Swift programming basics and build your first iOS app! Authentication & Authorization: OAuth中级Learn to implement the OAuth 2.0 framework to allow users to securely and easily login to your web applications. 创建分析数据集初级学习如何在 Alteryx 程序中识别、纠正、格式化和混合多种来源的数字，认识一种新的数据处理方式。合作企业 Alteryx  配置 Linux 网站服务器高级搭建和配置一个数据驱动的网络应用，并确保 Ubuntu Linux 网络应用服务器的安全性。 HTTP 和 Web 服务器中级HTTP 是网络的基本协议。在这门课程中，使用 Python 和命令行探索它的原理。 Get Your Startup Started中级Acquire the know-how necessary to see your business grow towards its next milestone. Android 系统性能高级应用的性能表现对用户很重要，所以这对开发人员十分重要。学会如何识别和处理 Android 应用的瓶颈问题，确保流畅的用户体验。合作企业 Google  Passwordless Login Solutions for iOS中级In this course you'll implement Account Kit and Facebook Login side by side in a sample app, test our login flow on a series of common use cases, and wrap things up with an introduction to Facebook’s Graph API.合作企业 Facebook  浏览器渲染优化高级这门课程将揭秘浏览器的渲染过程，让你更容易打造出高性能的网站应用。合作企业 Google  Data Analysis and Visualization中级This course will introduce students to the field by coveri ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ICP：沪ICP备16009837号 “纳米学位” 是优达学城的（Udacity）注册商标 京ICP证160887号 优达学城不授予传统意义上的学位证书，优达学城的 “纳米学位” 项目代表我们与企业合作伙伴的深度合作，他们与我们共同开发课程内容，并雇佣我们的毕业生

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just ike in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
# Find all course summaries
summaries = soup.find_all("div", {"class":"course-summary-card"})
print('Number of Courses:', len(summaries))
# Out:
# Number of Courses: 189

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(summaries[0].prettify())
# Out:
# <div _ngcontent-sc247="" class="course-summary-card row row-gap-medium ng-star-inserted">
#  <div _ngcontent-sc247="" class="col-sm-3">
#   <!-- -->
#   <img _ngcontent-sc247="" alt="机器学习云部署 (英)" class="course-thumb img-responsive img-bordered center-block ng-star-inserted" height="170" src="https://static-assets.s3.cn-north-1.amazonaws.com.cn/degrees/nd895-cn/nd_card.jpg" width="290"/>
#   <!-- -->
#   <!-- -->
#  </div>
#  <div _ngcontent-sc247="" class="col-sm-9 course-text">
#   <div _ngcontent-sc247="" class="row">
#    <div _ngcontent-sc247="" class="col-sm-8">
#     <h3 _ngcontent-sc247="" class="h-slim">
#      <a _ngcontent-sc247="" href="/course/machine-learning-cloud-deployment-nanodegree--nd895-cn">
#       机器学习云部署 (英)
#      </a>
#      <span _ngcontent-sc247="" class="badges">
#       <!-- -->
#      </span>
#     </h3>
#    </div>
#    <div _ngcontent-sc247="" class="col-sm-4 hidden-xs">
#     <!-- -->
#     <span _ngcontent-sc247="" class="caption text-right ng-star-inserted">
#      <span _ngcontent-sc247="" class="icon-level course-info-bar-icon icon-level-advanced" classname="icon-level course-info-bar-icon icon-level-advanced" data-course-level-icon="">
#      </span>
#      <span _ngcontent-sc247="" class="capitalize" data-course-level-label="">
#       高级
#      </span>
#     </span>
#    </div>
#   </div>
#   <div _ngcontent-sc247="">
#    <!-- -->
#    <span _ngcontent-sc247="" class="ng-star-inserted">
#     快速掌握如何将机器学习模型部署在云端
#    </span>
#   </div>
#   <!-- -->
#  </div>
# </div>

# %% [markdown]
# Look for selectors that contain the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
summaries[0].select_one("h3").get_text().strip()
# Out:
# '机器学习云部署 (英)'

# %%
# Extract school
summaries[0].select_one("h4").get_text().strip()
# 中文网站结构没有 h4 ，会报错（英文的有）
# 在国内会自动转成中文
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-43f80de64066> in <module>
#       1 # Extract school
# ----> 2 summaries[0].select_one("h4").get_text().strip()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for summary in summaries:
    # append name and school of each summary to courses list
    title = summary.select_one("h3").get_text().strip()
    # school = summary.select_one("h4").get_text().strip()
    # courses.append((title, school))
    courses.append((title))

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
# Out:
# 189 course summaries found. Sample:
# ['机器学习云部署 (英)',
#  'Java 开发工程师 (英)',
#  'AI 产品经理 (英)',
#  '数据挖掘 求职直通班',
#  '市场营销分析 (英)',
#  '传感器融合 (英)',
#  '数据洞察与说服技巧 (英)',
#  '云计算软件开发 (英)',
#  '云计算 DevOps (英)',
#  'AI 求职直通班',
#  'C++ 程序设计 (英)',
#  '数据结构与算法 (英)',
#  'Python 编程入门',
#  '28 天入门 Python',
#  '高频算法面试题精讲',
#  'Python 人工智能入门',
#  '数据分析（入门）',
#  '数据工程师 (英)',
#  '商业数据分析',
#  'AI 量化投资 (英)']
